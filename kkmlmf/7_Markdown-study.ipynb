# %% [markdown]
# # Markdwon代码学习

# %% [markdown]
# Markdown 是一种轻量级标记语言，它允许人们使用易读易写的纯文本格式（.md）编写文档，然后转换成有效的 XHTML（或者HTML）文档。

# %% [markdown]
# ## Markdown基础学习
# 参考文档：https://mp.weixin.qq.com/s/uimFjG3czrkgWhIxbTyoRw

# %% [markdown]
# 1. 文本加粗、斜体、删除线
# ```markdown
# **Markdwon**
# *markdown*  _markdown_
# ~~markdown~~
# ```

# %% [markdown]
# **Markdwon**
# *markdown*  _markdown_
# ~~markdown~~

# %% [markdown]
# 2. 文本换行（文本后插入两个空格或者直接空一行）
# ```
# 这是markdown学习指南
# 包含很多基础知识
#
# 这是markdown学习指南
# 包含很多基础知识
# ```

# %% [markdown]
# 这是markdown学习指南
# 包含很多基础知识
#
# 这是markdown学习指南
# 包含很多基础知识

# %% [markdown]
# 3. 引用
# ```markdown
# > 欢迎学习**Markdwon**
# >
# > >markdown
# ```

# %% [markdown]
# > 欢迎学习**Markdwon**
# >
# > > markdown

# %% [markdown]
# 4. 无序列表
# ```
# - 学习Markdown
#   - 学习基础用法
#     - 学习无序列表
# ```

# %% [markdown]
# - 学习Markdown
#   - 学习基础用法
#     - 学习无序列表

# %% [markdown]
# 5. 有序列表
# ```
# 1. 学习Markdown
# 2. 学习基础用法
# 3. 学习无序列表
# ```

# %% [markdown]
# 1. 学习Markdown
# 2. 学习基础用法
# 3. 学习无序列表

# %% [markdown]
# 6. 多级标题
# ```
# # 一级标题
# ## 二级标题
# ### 三级标题
# #### 四级标题
# ```

# %% [markdown]
# ### 三级标题
# #### 四级标题

# %% [markdown]
# 7. 代码展示
# `import torch`
# `import gc`
# ```python
# def CleanMemory():
#     torch.cuda.empty_cache()
#     gc.collect()
#     print_gpu_memory("缓存已清理")
# ```

# %% [markdown]
# `import torch`
# `import gc`
# ```python
# def CleanMemory():
#     torch.cuda.empty_cache()
#     gc.collect()
#     print_gpu_memory("缓存已清理")
# ```

# %% [markdown]
# 8. 插入链接
# ```markdown
# kkmlmf的仓库 [访问kkmlmf的仓库](https://github.com/kkmlimingfeng/Artificial-Intelligence-Learning "kkmlmf的仓库")
# ```

# %% [markdown]
# kkmlmf的仓库 [访问kkmlmf的仓库](https://github.com/kkmlimingfeng/Artificial-Intelligence-Learning "kkmlmf的仓库")

# %% [markdown]
# 9. 分割线
# ```markdown
# ---
#
# markdown1
#
# ---
#
# markdown1
#
# ---
# ```

# %% [markdown]
# ---
#
# markdown1
#
# ---
#
# markdown1
#
# ---

# %% [markdown]
# 10. 表格
# ```markdown
# | 模型 | 精确率 | 召回率 |
# | --- | --- | --- |
# | <font style="color: red">baseline</font> | 60% | **70%** |
# | a | 61% | <u>69%</u> |
# | a+b | <u>62%</u> | 68% |
# | a+b+c | **65%** | 65% |
# ```

# %% [markdown]
# | 模型 | 精确率 | 召回率 |
# | --- | --- | --- |
# | <font style="color: red">baseline</font> | 60% | **70%** |
# | a | 61% | <u>69%</u> |
# | a+b | <u>62%</u> | 68% |
# | a+b+c | **65%** | 65% |

# %% [markdown]
# 11. 插入图片(用img标签可以调整宽高)
# ```
# <img src="data/Markdown-study/kokomi.png" style="width:25%;">
#
# <img src="data/Markdown-study/kokomi.png" width="50%">
#
# ![](data/Markdown-study/kokomi.png)
# ```

# %% [markdown]
# <img src="data/Markdown-study/kokomi.png" style="width:25%;">
#
# <img src="data/Markdown-study/kokomi.png" width="50%">
#
# ![](data/Markdown-study/kokomi.png)

# %% [markdown]
# 12. 简单公式
# ```markdown
# 行内公式$1+1=2$
#
# 块级公式$$2+2=4$$
# ```

# %% [markdown]
# 行内公式$1+1=2$
#
# 块级公式$$2+2=4$$

# %% [markdown]
# ## Markdown公式编辑

# %% [markdown]
# ### 符号大全

# %% [markdown]
# | 名称 | 大写 | 大写LaTeX | 小写 | 小写LaTeX |
# |------|------|----------|------|----------|
# | alpha | A | A | α | \alpha |
# | beta | B | B | β | \beta |
# | gamma | Γ | \Gamma | γ | \gamma |
# | delta | Δ | \Delta | δ | \delta |
# | epsilon | E | E | ϵ | \epsilon |
# | zeta | Z | Z | ζ | \zeta |
# | eta | H | H | η | \eta |
# | theta | Θ | \Theta | θ | \theta |
# | iota | I | I | ι | \iota |
# | kappa | K | K | κ | \kappa |
# | lambda | Λ | \Lambda | λ | \lambda |
# | mu | M | M | μ | \mu |
# | nu | N | N | ν | \nu |
# | xi | Ξ | \Xi | ξ | \xi |
# | omicron | O | O | ο | \omicron |
# | pi | Π | \Pi | π | \pi |
# | rho | P | P | ρ | \rho |
# | sigma | Σ | \Sigma | σ | \sigma |
# | tau | T | T | τ | \tau |
# | upsilon | Υ | \Upsilon | υ | \upsilon |
# | phi | Φ | \Phi | ϕ | \phi |
# | chi | X | X | χ | \chi |
# | psi | Ψ | \Psi | ψ | \psi |
# | omega | Ω | \Omega | ω | \omega |
# | ell_p |  |  | ℓp | \ell_p |

# %% [markdown]
# | code | 小写 | code | 大写LaTeX | var-code | 变量 |
# |------|------|------|----|------|----------|
# | \epsilon | ϵ | E | E | \varepsilon | ε |
# | \theta | θ | \Theta | Θ | \vartheta | ϑ |
# | \rho | ρ | P | P | \varrho | ϱ |
# | \sigma | σ | \Sigma | Σ | \varsigma | ς |
# | \phi | ϕ | \Phi | Φ | \varphi | φ |

# %% [markdown]
# ### 运算符

# %% [markdown]
# | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 |
# |----------|----------|----------|----------|----------|----------|
# | \pm | ± | \times | × | \div | ÷ |
# | \nmid | ∤ | \mid | ∣ | \cdot | ⋅ |
# | \ldots | … | \cdots | ⋯ | \circ | ∘ |
# | \bigodot | ⨀ | \bigotimes | ⨂ | \bigoplus | ⨁ |
# | \geq | ≥ | \neq | ≠ | \approx | ≈ |
# | \leq | ≤ | \lt | < | \gt | > |
# | \sum | ∑ | \prod | ∏ | \coprod | ∐ |
# | \sim | ∼ | \equiv | ≡ | \star | ⋆ |
# | \ast | ∗ | \bullet | ∙ | \prec | ≺ |
# | \succ | ≻ | \oplus | ⊕ | \preceq | ⪯ |
# | \succeq | ⪰ | \pmod n | (mod n) | \vdots | ⋱ |

# %% [markdown]
# | LaTeX代码 | 显示 | LaTeX代码 | 显示 | LaTeX代码 | 显示 |
# |---|---|---|---|---|---|
# | \log | $\log$ | \lg | $\lg$ | \ln | $\ln$ |

# %% [markdown]
# | LaTeX代码 | 名称 | 显示符号 | LaTeX代码 | 名称 | 显示符号 | LaTeX代码 | 名称 | 显示符号 |
# |----------|------|----------|----------|------|----------|----------|------|----------|
# | \emptyset | 空集 | ∅ | \in | 属于 | ∈ | \notin | 不属于 | ∉ |
# | \subset | 子集 | ⊂ | \supset | 超集 | ⊃ | \supseteq | 超集或等于 | ⊇ |
# | \subseteq | 子集或等于 | ⊆ | \bigcap | 大交集 | ⋂ | \bigcup | 大并集 | ⋃ |
# | \setminus | 差集 | ∖ | \cap | 交集 | ∩ | \cup | 并集 | ∪ |
# | \varnothing | 空 | ∅ | \bigvee | 大或 | ⋁ | \bigwedge | 大与 | ⋀ |
# | \subsetneq | 真子集 | ⊊ | \biguplus | 大异或 | ⨄ |  |  |  |

# %% [markdown]
# | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 |
# |----------|----------|----------|----------|----------|----------|
# | 30^\circ | $30^\circ$ | \bot | ⊥ | \angle A | ∠A |
# | \sin | sin | \cos | cos | \tan | tan |
# | \csc | csc | \sec | sec | \cot | cot |
# | \arcsin | arcsin | \arccos | arccos | \arctan | arctan |

# %% [markdown]
# | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 |
# |----------|----------|----------|----------|----------|----------|
# | \int | ∫ | \iint | ∬ | \iiint | ∭ |
# | \iiiint | ⨌ | \oint | ∮ | \prime | ′ |
# | \lim | lim | \infty | ∞ | \nabla | ∇ |

# %% [markdown]
# | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 |
# |----------|----------|----------|----------|----------|----------|
# | \because | ∵ | \therefore | ∴ | \forall | ∀ |
# | \exists | ∃ | \not\subset | ⊄ | \not< | $ |
# | \not> | ≯ | \not= | ≠ | \land | ∧ |
# | \lnot | ¬ | \exists | ∃ | \lor | ∨ |
# | \forall | ∀ | \top | ⊤ | \bot | ⊥ |
# | \vdash | ⊢ | \vDash | ⊨ |  |  |

# %% [markdown]
# | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 |
# |----------|----------|----------|----------|----------|----------|
# | \binom{n+1}{2k} | $\binom{n+1}{2k}$ | {n+1 \choose 2k} | ${n+1 \choose 2k}$ |  |  |
# | \infty | $\infty$ | \aleph_o | $\aleph_o$ | \nabla | $\nabla$ |
# | \Im | $\Im$ | \Re | $\Re$ |  |  |

# %% [markdown]
# | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 | LaTeX代码 | 显示符号 |
# |----------|----------|----------|----------|----------|----------|
# | \rightarrow | → | \leftarrow | ← | \longrightarrow | ⟶ | \longleftarrow | ⟵ |
# | \Rightarrow | ⇒ | \Leftarrow | ⇐ | \Longrightarrow | ⟹ | \Longleftarrow | ⟸ |
# | \uparrow | ↑ | \downarrow | ↓ | \mapsto | ↦ | \to | → |
# | \Uparrow | ⇑ | \Downarrow | ⇓ | \Longleftrightarrow | ⟺ |  |  |

# %% [markdown]
# | LaTeX代码 | 显示 | LaTeX代码 | 显示 |
# |----------|------|----------|------|
# | \hat{xy} | $ \hat{xy} $ | \widehat{xyz} | $ \widehat{xyz} $ |
# | \tilde{xy} | $ \tilde{xy} $ | \widetilde{xyz} | $ \widetilde{xyz} $ |
# | \check{x} | $ \check{x} $ | \breve{y} | $ \breve{y} $ |
# | \grave{x} | $ \grave{x} $ | \acute{y} | $ \acute{y} $ |
# | \dot{x} | $ \dot{x} $ | \ddot{x} | $ \ddot{x} $ |
# | \dot{\dot{x}} | $ \dot{\dot{x}} $ | \vec{x} | $ \vec{x} $ |
# | \fbox{a+b+c+d} | $ \fbox{a+b+c+d} $ | \overleftarrow{a+b+c+d} | $ \overleftarrow{a+b+c+d} $ |
# | \overrightarrow{a+b+c+d} | $ \overrightarrow{a+b+c+d} $ | \overleftrightarrow{a+b+c+d} | $ \overleftrightarrow{a+b+c+d} $ |
# | \underleftarrow{a+b+c+d} | $ \underleftarrow{a+b+c+d} $ | \underrightarrow{a+b+c+d} | $ \underrightarrow{a+b+c+d} $ |
# | \underline{a+b+c+d} | $ \underline{a+b+c+d} $ | \overbrace{a+b+c+d}^{Sample} | $ \overbrace{a+b+c+d}^{Sample} $ |
# | \underbrace{a+b+c+d}_{Sample} | $ \underbrace{a+b+c+d}_{Sample} $ | \overbrace{a+\underbrace{b+c}_{1.0}+d}^{2.0} | $ \overbrace{a+\underbrace{b+c}_{1.0}+d}^{2.0} $ |
# | \underbrace{a\cdot a\cdots a}_{b\text{ times}} | $ \underbrace{a\cdot a\cdots a}_{b\text{ times}} $ |  |  |

# %% [markdown]
# ### 表格和矩阵

# %% [markdown]
# 表格

# %% [markdown]
# $$
# \begin{array}{c|lcr}
# n & \text{Left} & \text{Center} & \text{Right} \\
# \hline
# 1 & 25 & 1 & 125 \\
# 2 & -1 & 1+10i & -1 \\
# 3 & 100 & 1 & 4 \\
# \end{array}
# $$

# %% [markdown]
# 矩阵

# %% [markdown]
# $
# \begin{bmatrix}
# 1 & x & x^2 & x^3 \\
# 1 & y & y^2 & y^3\\
# 1 & z & z^2 & z^3\\
# \end{bmatrix}
# \begin{Bmatrix}
# 1 & 2 & \cdots & n \\
# 2 & \ddots & \cdots & \vdots \\
# \vdots & \vdots & \ddots & 5 \\
# n & \cdots & 5 & 1
# \end{Bmatrix}
# \begin{pmatrix}
# A & \big| & B \\
# \hline
# C & \big| & D
# \end{pmatrix}
# \begin{vmatrix}
# x_{11} & x_{12} & \cdots & x_{1n} \\
# x_{21} & x_{22} & \cdots & x_{2n} \\
# \vdots & \vdots & \ddots & \vdots \\
# x_{m1} & x_{m2} & \cdots & x_{mn}
# \end{vmatrix}
# \begin{Vmatrix}
# \text{行1列1} & \text{行1列2} \\
# \text{行2列1} & \text{行2列2}
# \end{Vmatrix}
# $

# %% [markdown]
# $$
# \begin{CD}
#     A @>>> B @>{\text{very long label}}>> C \\
#     @. @AAA @| \\
#     D @= E @<<< F
# \end{CD}
# $$

# %% [markdown]
# ## 更多公式可以参考
# https://blog.csdn.net/m0_74409046/article/details/145847961

# %% [markdown]
# ## Markdown画图（Mermaid）
# 参考文档:https://mermaid.nodejs.cn/

# %% [markdown]
# **仅介绍常用的**

# %% [markdown]
# ### 流程图

# %% [markdown]
# - TB - 从上到下
# - TD - 自上而下 / 与从上到下相同
# - BT - 从底部到顶部
# - RL - 从右到左
# - LR - 从左到右

# %% [markdown]
# ```
# ```mermaid
# flowchart LR
#     markdown["`This **is** _Markdown_ ❤`"]
#     newLines["`Line1
#     Line 2
#     Line 3`"]
#     newLine1([体育场形状])
#     newLine2(圆角)
#     newLine3((圆))
#     newLine4[[框框]]
#     newLine5[(圆柱)]
#     newLine6>奇怪形状]
#     newLine7{{六边形}}
#     newLine8{菱形}
#     newLine9[/平行四边形/]
#     newLine10[/梯形\]
#     newLine11(((双圆)))
#     newLine12[\可以放在外面/]
#     markdown --> newLines
#     newLines --> newLine1
#     newLines --> newLine3
#     newLines -- 可以加文字 --> newLine4
#     newLine1 --> newLine2
#     newLine2 --> newLine3
#     newLine3 --> newLine5
#     newLine5 --> newLine11
#     newLine4 --> newLine6
#     newLine6 --> newLine7
#     newLine6 --> newLine8
#     newLine8 --> newLine9
#     newLine9 --> newLine10
# ```

# %% [markdown]
# ```mermaid
# flowchart LR
#     markdown["`This **is** _Markdown_ ❤`"]
#     newLines["`Line1
#     Line 2
#     Line 3`"]
#     newLine1([体育场形状])
#     newLine2(圆角)
#     newLine3((圆))
#     newLine4[[框框]]
#     newLine5[(圆柱)]
#     newLine6>奇怪形状]
#     newLine7{{六边形}}
#     newLine8{菱形}
#     newLine9[/平行四边形/]
#     newLine10[/梯形\]
#     newLine11(((双圆)))
#     newLine12[\可以放在外面/]
#     markdown --> newLines
#     newLines --> newLine1
#     newLines --> newLine3
#     newLines -- 可以加文字 --> newLine4
#     newLine1 --> newLine2
#     newLine2 --> newLine3
#     newLine3 --> newLine5
#     newLine5 --> newLine11
#     newLine4 --> newLine6
#     newLine6 --> newLine7
#     newLine6 --> newLine8
#     newLine8 --> newLine9
#     newLine9 --> newLine10

# %% [markdown]
# ### 类图

# %% [markdown]
# ```
# ```mermaid
# classDiagram
#     note "From Duck till Zebra"
#     Animal <|-- Duck
#     note for Duck "can fly<br>can swim<br>can dive<br>can help in debugging"
#     Animal <|-- Fish
#     Animal <|-- Zebra
#     Animal : +int age
#     Animal : +String gender
#     Animal: +isMammal()
#     Animal: +mate()
#     class Duck{
#         +String beakColor
#         +swim()
#         +quack()
#     }
#     class Fish{
#         -int sizeInFeet
#         -canEat()
#     }
#     class Zebra{
#         +bool is_wild
#         +run()
#     }

# %% [markdown]
# ```mermaid
# classDiagram
#     note "From Duck till Zebra"
#     Animal <|-- Duck
#     note for Duck "can fly<br>can swim<br>can dive<br>can help in debugging"
#     Animal <|-- Fish
#     Animal <|-- Zebra
#     Animal : +int age
#     Animal : +String gender
#     Animal: +isMammal(a)
#     Animal: +mate()
#     class Duck{
#         +String beakColor
#         +swim()
#         +quack()
#     }
#     class Fish{
#         -int sizeInFeet
#         -canEat()
#     }
#     class Zebra{
#         +bool is_wild
#         +run()
#     }

# %% [markdown]
# ### 状态图
# 使用direction LR可以改变方向

# %% [markdown]
# ```
# ```mermaid
# stateDiagram-v2
#     state if_state <<choice>>
#     [*] --> IsPositive
#     IsPositive --> if_state
#     if_state --> False: if n < 0
#     if_state --> True : if n >= 0

# %% [markdown]
# ```mermaid
# stateDiagram-v2
#     state if_state <<choice>>
#     [*] --> IsPositive
#     IsPositive --> if_state
#     if_state --> False: if n < 0
#     if_state --> True : if n >= 0

# %% [markdown]
# ```
# ```mermaid
# stateDiagram-v2
#     direction LR
#     [*] --> Still
#     Still --> [*]
#
#     Still --> Moving
#     Moving --> Still
#     Moving --> Crash
#     Crash --> [*]

# %% [markdown]
# ```mermaid
# stateDiagram-v2
#     direction LR
#     [*] --> Still
#     Still --> [*]
#
#     Still --> Moving
#     Moving --> Still
#     Moving --> Crash
#     Crash --> [*]

# %% [markdown]
# ```
# ```mermaid
# stateDiagram-v2
#     direction LR
#     [*] --> First
#     First --> Second
#     First --> Third
#
#     state First {
#         [*] --> fir
#         fir --> [*]
#     }
#     state Second {
#         direction LR
#         [*] --> sec
#         sec --> [*]
#     }
#     state Third {
#         direction LR
#         [*] --> thi
#         thi --> [*]
#     }

# %% [markdown]
# ```mermaid
# stateDiagram-v2
#     direction LR
#     [*] --> First
#     First --> Second
#     First --> Third
#
#     state First {
#         [*] --> fir
#         fir --> [*]
#     }
#     state Second {
#         direction LR
#         [*] --> sec
#         sec --> [*]
#     }
#     state Third {
#         direction LR
#         [*] --> thi
#         thi --> [*]
#     }

# %% [markdown]
# ### 甘特图

# %% [markdown]
# ```
# ```mermaid
# gantt
#     title A Gantt Diagram
#     dateFormat YYYY-MM-DD
#     section Section
#         A task          :a1, 2026-05-01, 30d
#         Another task    :after a1, 20d
#     section Another
#         Task in Another :2026-05-12, 12d
#         another task    :24d

# %% [markdown]
# ```mermaid
# gantt
#     title A Gantt Diagram
#     dateFormat YYYY-MM-DD
#     section Section
#         A task          :a1, 2026-05-01, 30d
#         Another task    :after a1, 20d
#     section Another
#         Task in Another :2026-05-12, 12d
#         another task    :24d

# %% [markdown]
# ```
# ```mermaid
# gantt
#     dateFormat  YYYY-MM-DD
#     title       Adding GANTT diagram functionality to mermaid
#     excludes    weekends
#     %% (`excludes` accepts specific dates in YYYY-MM-DD format, days of the week ("sunday") or "weekends", but not the word "weekdays".)
#
#     section A section
#     Completed task            :done,    des1, 2014-01-06,2014-01-08
#     Active task               :active,  des2, 2014-01-09, 3d
#     Future task               :         des3, after des2, 5d
#     Future task2              :         des4, after des3, 5d
#
#     section Critical tasks
#     Completed task in the critical line :crit, done, 2014-01-06,24h
#     Implement parser and jison          :crit, done, after des1, 2d
#     Create tests for parser             :crit, active, 3d
#     Future task in critical line        :crit, 5d
#     Create tests for renderer           :2d
#     Add to mermaid                      :until isadded
#     Functionality added                 :milestone, isadded, 2014-01-25, 0d
#
#     section Documentation
#     Describe gantt syntax               :active, a1, after des1, 3d
#     Add gantt diagram to demo page      :after a1  , 20h
#     Add another diagram to demo page    :doc1, after a1  , 48h
#
#     section Last section
#     Describe gantt syntax               :after doc1, 3d
#     Add gantt diagram to demo page      :20h
#     Add another diagram to demo page    :48h

# %% [markdown]
# ```mermaid
# gantt
#     dateFormat  YYYY-MM-DD
#     title       Adding GANTT diagram functionality to mermaid
#     excludes    weekends
#     %% (`excludes` accepts specific dates in YYYY-MM-DD format, days of the week ("sunday") or "weekends", but not the word "weekdays".)
#
#     section A section
#     Completed task            :done,    des1, 2014-01-06,2014-01-08
#     Active task               :active,  des2, 2014-01-09, 3d
#     Future task               :         des3, after des2, 5d
#     Future task2              :         des4, after des3, 5d
#
#     section Critical tasks
#     Completed task in the critical line :crit, done, 2014-01-06,24h
#     Implement parser and jison          :crit, done, after des1, 2d
#     Create tests for parser             :crit, active, 3d
#     Future task in critical line        :crit, 5d
#     Create tests for renderer           :2d
#     Add to mermaid                      :until isadded
#     Functionality added                 :milestone, isadded, 2014-01-25, 0d
#
#     section Documentation
#     Describe gantt syntax               :active, a1, after des1, 3d
#     Add gantt diagram to demo page      :after a1  , 20h
#     Add another diagram to demo page    :doc1, after a1  , 48h
#
#     section Last section
#     Describe gantt syntax               :after doc1, 3d
#     Add gantt diagram to demo page      :20h
#     Add another diagram to demo page    :48h

# %% [markdown]
# ### 饼图

# %% [markdown]
# ```
# ```mermaid
# pie showData
#     title Key elements in Product X
#     "Calcium" : 42.96
#     "Potassium" : 50.05
#     "Magnesium" : 10.01
#     "Iron" :  5

# %% [markdown]
# ```mermaid
# pie showData
#     title Key elements in Product X
#     "Calcium" : 42.96
#     "Potassium" : 50.05
#     "Magnesium" : 10.01
#     "Iron" :  5

# %% [markdown]
# ### 象限图

# %% [markdown]
# ```
# ```mermaid
# quadrantChart
#     title Reach and engagement of campaigns
#     x-axis Low Reach --> High Reach
#     y-axis Low Engagement --> High Engagement
#     quadrant-1 We should expand
#     quadrant-2 Need to promote
#     quadrant-3 Re-evaluate
#     quadrant-4 May be improved
#     Campaign A: [0.3, 0.6]
#     Campaign B: [0.45, 0.23]
#     Campaign C: [0.57, 0.69]
#     Campaign D: [0.78, 0.34]
#     Campaign E: [0.40, 0.34]
#     Campaign F: [0.35, 0.78]

# %% [markdown]
# ```mermaid
# quadrantChart
#     title Reach and engagement of campaigns
#     x-axis Low Reach --> High Reach
#     y-axis Low Engagement --> High Engagement
#     quadrant-1 We should expand
#     quadrant-2 Need to promote
#     quadrant-3 Re-evaluate
#     quadrant-4 May be improved
#     Campaign A: [0.3, 0.6]
#     Campaign B: [0.45, 0.23]
#     Campaign C: [0.57, 0.69]
#     Campaign D: [0.78, 0.34]
#     Campaign E: [0.40, 0.34]
#     Campaign F: [0.35, 0.78]

# %% [markdown]
# ### 思维导图

# %% [markdown]
# ```
# ```mermaid
# mindmap
#   root((LLM 微调 / 对齐))
#     全量微调
#       SFT
#     参数高效（PEFT）
#       LoRA / QLoRA
#       Prompt Tuning
#       Prefix Tuning
#       Adapter / IA3
#     对齐 / 偏好优化
#       RLHF（PPO）
#       DPO
#       RLAIF
#       其他变体（GRPO 等）

# %% [markdown]
# ```mermaid
# mindmap
#   root((LLM 微调 / 对齐))
#     全量微调
#       SFT
#     参数高效（PEFT）
#       LoRA / QLoRA
#       Prompt Tuning
#       Prefix Tuning
#       Adapter / IA3
#     对齐 / 偏好优化
#       RLHF（PPO）
#       DPO
#       RLAIF
#       其他变体（GRPO 等）

# %% [markdown]
# ### 树图

# %% [markdown]
# ```
# ```mermaid
# treemap-beta
# "Products"
#     "Electronics"
#         "Phones": 50
#         "Computers": 30
#         "Accessories": 20
#     "Clothing"
#         "Men's": 40
#         "Women's": 40

# %% [markdown]
# ```mermaid
# treemap-beta
# "Products"
#     "Electronics"
#         "Phones": 50
#         "Computers": 30
#         "Accessories": 20
#     "Clothing"
#         "Men's": 40
#         "Women's": 40

# %% [markdown]
# ```
# ```mermaid
# treemap-beta
# "Section 1"
#     "Leaf 1.1": 12
#     "Section 1.2":::class1
#       "Leaf 1.2.1": 12
# "Section 2"
#     "Leaf 2.1": 20:::class1
#     "Leaf 2.2": 25
#     "Leaf 2.3": 12
#
# classDef class1 fill:red,color:blue,stroke:#FFD600;

# %% [markdown]
# ```mermaid
# treemap-beta
# "Section 1"
#     "Leaf 1.1": 12
#     "Section 1.2":::class1
#       "Leaf 1.2.1": 12
# "Section 2"
#     "Leaf 2.1": 20:::class1
#     "Leaf 2.2": 25
#     "Leaf 2.3": 12
#
# classDef class1 fill:red,color:blue,stroke:#FFD600;

# %% [markdown]
# ### 雷达图

# %% [markdown]
# ```
# ```mermaid
# radar-beta
#   axis m["Math"], s["Science"], e["English"]
#   axis h["History"], g["Geography"], a["Art"]
#   curve a["Alice"]{85, 90, 80, 70, 75, 90}
#   curve b["Bob"]{70, 75, 85, 80, 90, 85}
#
#   max 100
#   min 0

# %% [markdown]
# ```mermaid
# radar-beta
#   axis m["Math"], s["Science"], e["English"]
#   axis h["History"], g["Geography"], a["Art"]
#   curve a["Alice"]{85, 90, 80, 70, 75, 90}
#   curve b["Bob"]{70, 75, 85, 80, 90, 85}
#
#   max 100
#   min 0

# %% [markdown]
# ```
# ```mermaid
# radar-beta
#   title Restaurant Comparison
#   axis food["Food Quality"], service["Service"], price["Price"]
#   axis ambiance["Ambiance"]
#
#   curve a["Restaurant A"]{4, 3, 2, 4}
#   curve b["Restaurant B"]{3, 4, 3, 3}
#   curve c["Restaurant C"]{2, 3, 4, 2}
#   curve d["Restaurant D"]{2, 2, 4, 3}
#
#   graticule polygon
#   max 5

# %% [markdown]
# ```mermaid
# radar-beta
#   title Restaurant Comparison
#   axis food["Food Quality"], service["Service"], price["Price"]
#   axis ambiance["Ambiance"]
#
#   curve a["Restaurant A"]{4, 3, 2, 4}
#   curve b["Restaurant B"]{3, 4, 3, 3}
#   curve c["Restaurant C"]{2, 3, 4, 2}
#   curve d["Restaurant D"]{2, 2, 4, 3}
#
#   graticule polygon
#   max 5

# %% [markdown]
# ### 桑基图

# %% [markdown]
# ```
# ```mermaid
# sankey
#
# Bio-conversion,Losses,26.862
#
# Bio-conversion,Solid,280.322
#
# Bio-conversion,Gas,81.144

# %% [markdown]
# ```mermaid
# sankey
#
# Bio-conversion,Losses,26.862
#
# Bio-conversion,Solid,280.322
#
# Bio-conversion,Gas,81.144
