# %% [markdown]
# # 所有要安装的包

# %% [markdown]
# **⚠️如果你使用的是uv包管理器，请在所有 pip 前加上 uv⚠️**

# %% [markdown]
# **检查python版本，最好>=3.10**

# %%
# !python --version
# Out:
# Python 3.12.12

# %% [markdown]
# （可选）安装uv

# %%
pip install uv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1_pytorch-study

# %% [markdown]
# **安装pytorch** 30、40、50系显卡均可(实测cuda12.5 ~ cuda13.0可行)

# %%
# !nvidia-smi
# Out:
# Wed Jun  3 11:39:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.58.02              Driver Version: 556.12         CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    On  |   00000000:01:00.0  On |                  N/A |
# | N/A   44C    P8             17W /   80W |    1829MiB /   6144MiB |      4%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
pip install torch==2.8.0 torchvision==0.23.0 torchaudio==2.8.0 --index-url https://download.pytorch.org/whl/cu128

# %% [markdown]
# **安装 einops tqdm**

# %%
# !pip install einops tqdm
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#
#    ---------------------------------------- 0/2 [tqdm]
#    -------------------- ------------------- 1/2 [einops]
#    ---------------------------------------- 2/2 [einops]
#
# ...

# %% [markdown]
# **安装pandas**

# %%
pip install pandas
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#      ---------------------------------------- 11.0/11.0 MB 57.1 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %% [markdown]
# **安装matplotlib**

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#      ---------------------------------------- 8.1/8.1 MB 55.9 MB/s  0:00:00
# ...
#      ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#      ---------------------------------------- 2.3/2.3 MB 43.8 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
# ...

# %% [markdown]
# ## 2_Transformer

# %% [markdown]
# **安装transformers**

# %%
pip install transformers
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#      --------------------------------------  11.8/12.0 MB 67.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.0/12.0 MB 62.4 MB/s  0:00:00
# ...
#      ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#      ---------------------------------------- 566.1/566.1 kB ?  0:00:00
# ...
#      ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#      ---------------------------------------- 2.7/2.7 MB 25.7 MB/s  0:00:00
# ...
#
#   Attempting uninstall: huggingface-hub
#
#     Found existing installation: huggingface_hub 1.2.3
#
#     Uninstalling huggingface_hub-1.2.3:
#
#       Successfully uninstalled huggingface_hub-1.2.3
#
#    ---------------------------------------- 0/3 [huggingface-hub]
#    ---------------------------------------- 0/3 [huggingface-hub]
# ...

# %%
#测试该代码（失败也没事）
from transformers import Qwen3Model

# %% [markdown]
# ## 3_StableDiffusion

# %% [markdown]
# **安装diffusers 和 accelerate**

# %%
# !pip install diffusers accelerate
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#      ---------------------------------------- 4.6/4.6 MB 55.6 MB/s  0:00:00
# ...
#      ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#      ---------------------------------------- 2.9/2.9 MB 42.6 MB/s  0:00:00
# ...
#
#    ---------- -----------------------------  3/11 [regex]
#    ------------------ ---------------------  5/11 [click]
#    ------------------------- --------------  7/11 [importlib_metadata]
#    ----------------------------- ----------  8/11 [huggingface-hub]
#    ----------------------------- ----------  8/11 [huggingface-hub]
#    ----------------------------- ----------  8/11 [huggingface-hub]
#    ----------------------------- ----------  8/11 [huggingface-hub]
#    ----------------------------- ----------  8/11 [huggingface-hub]
#    ----------------------------- ----------  8/11 [huggingface-hub]
# ...

# %% [markdown]
# ### lightx2v相关

# %% [markdown]
# **安装triton**(torch2.8对应trition3.4)

# %%
pip install -U "triton-windows<3.5"
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ---------------------------------------- 0.0/42.7 MB ? eta -:--:--
#      --- ------------------------------------ 4.2/42.7 MB 21.0 MB/s eta 0:00:02
#      ------ --------------------------------- 7.3/42.7 MB 18.9 MB/s eta 0:00:02
#      ---------- ---------------------------- 11.5/42.7 MB 19.5 MB/s eta 0:00:02
#      ------------- ------------------------- 15.2/42.7 MB 19.1 MB/s eta 0:00:02
#      ---------------- ---------------------- 18.4/42.7 MB 18.4 MB/s eta 0:00:02
#      -------------------- ------------------ 22.5/42.7 MB 18.8 MB/s eta 0:00:02
#      ------------------------ -------------- 27.0/42.7 MB 19.0 MB/s eta 0:00:01
#      --------------------------- ----------- 30.4/42.7 MB 19.1 MB/s eta 0:00:01
#      -------------------------------- ------ 35.1/42.7 MB 19.4 MB/s eta 0:00:01
#      ----------------------------------- --- 38.8/42.7 MB 19.3 MB/s eta 0:00:01
# ...

# %% [markdown]
# **安装flash-attn2**

# %%
pip install ./package/flash_attn-2.8.2+cu128torch2.8.0cxx11abiFALSE-cp312-cp312-win_amd64.whl
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Processing d:\cs\notebookworkspace\pytorch-study\package\flash_attn-2.8.2+cu128torch2.8.0cxx11abifalse-cp312-cp312-win_amd64.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **linux版flash-attn2.8.3链接**：https://release-assets.githubusercontent.com/github-production-release-asset/494232964/8951552b-75d9-4ee8-afa5-c69ec25bc405?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-05-22T06%3A15%3A33Z&rscd=attachment%3B+filename%3Dflash_attn-2.8.3%2Bcu12torch2.8cxx11abiFALSE-cp312-cp312-linux_x86_64.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-05-22T05%3A14%3A45Z&ske=2026-05-22T06%3A15%3A33Z&sks=b&skv=2018-11-09&sig=4fMOcXMWcuvDAlFsLpUSuAbG5q%2B7zfxBDNO9o76M4QY%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3OTQzMDUzMywibmJmIjoxNzc5NDI2OTMzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.HbcCwBXPEblA5Jy_ufIcvWCHRT1pioHRoQeiQXpF36A&response-content-disposition=attachment%3B%20filename%3Dflash_attn-2.8.3%2Bcu12torch2.8cxx11abiFALSE-cp312-cp312-linux_x86_64.whl&response-content-type=application%2Foctet-stream

# %%
pip install ./package/flash_attn-2.8.3+cu12torch2.8cxx11abiFALSE-cp312-cp312-linux_x86_64.whl

# %% [markdown]
# **安装SageAttention 2** 注意力算子

# %%
pip install ./package/sageattention-2.2.0+cu128torch2.8.0-cp312-cp312-win_amd64.whl
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Processing d:\cs\notebookworkspace\pytorch-study\package\sageattention-2.2.0+cu128torch2.8.0-cp312-cp312-win_amd64.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **安装qtorch（量化核心依赖）**

# %%
pip install qtorch -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 4_Mamba3

# %%
# pip install torch einops

# %% [markdown]
# ## 6_LMandLora

# %%
pip install transformers accelerate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 模型下载

# %%
pip install modelscope
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 模型部署

# %%
pip install vllm==0.10.2 openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 模型微调

# %%
pip install datasets peft trl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 8_Agent

# %%
pip install requests openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tavily-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# RAG

# %%
pip install langchain langchain-community langchain-text-splitters langchain-openai chromadb pypdf sentence-transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 9_
