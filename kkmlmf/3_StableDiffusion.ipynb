# %%
#pip install diffusers transformers
# !pip show diffusers transformers pillow accelerate
# Out:
# Name: diffusers
# Version: 0.36.0
# Summary: State-of-the-art diffusion in PyTorch and JAX.
# Home-page: https://github.com/huggingface/diffusers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/diffusers/graphs/contributors)
# Author-email: diffusers@huggingface.co
# License: Apache 2.0 License
# Location: D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages
# Requires: filelock, httpx, huggingface-hub, importlib_metadata, numpy, Pillow, regex, requests, safetensors
# Required-by:
# ---
# Name: transformers
# Version: 4.57.3
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by:
# ---
# Name: pillow
# Version: 12.0.0
# Summary: Python Imaging Library (fork)
# Home-page: https://python-pillow.github.io
# Author:
# Author-email: "Jeffrey A. Clark" <aclark@aclark.net>
# License-Expression: MIT-CMU
# Location: D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages
# Requires:
# Required-by: diffusers, matplotlib, torchvision
# ---
# Name: accelerate
# Version: 1.12.0
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages
# Requires: huggingface_hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by:

# %% [markdown]
# # 学习AI生图

# %% [markdown]
# **国内运行这个！！！！！**

# %%
import os
os.environ["HUGGINGFACE_HUB_ENDPOINT"] = "https://hf-mirror.com"  # 核心！
os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"  # 向下兼容，双保险

# %matplotlib inline
import torch
import matplotlib.pyplot as plt
from diffusers import StableDiffusionPipeline
import accelerate
from PIL import Image

from huggingface_hub import hf_hub_url
download_url = hf_hub_url(
    repo_id="hakurei/waifu-diffusion",
    filename="model_index.json"
)
download_url #显示  https://hf-mirror.com/hakurei/waifu-diffusion/resolve/main/model_index.json
# Out:
# W0113 16:51:52.441000 11672 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# 'https://hf-mirror.com/hakurei/waifu-diffusion/resolve/main/model_index.json'

# %% [markdown]
# **网络好用这个**

# %%
# 关键：让matplotlib图嵌入notebook显示
# %matplotlib inline
import torch
import os
import matplotlib.pyplot as plt
from PIL import Image   #（这个就是pillow）
import accelerate
from diffusers import StableDiffusionPipeline

# %% [markdown]
# ## 先跑一个demo

# %% [markdown]
# 该模型**5.1G**,运行需要**4G显存**
# 导入必备的包

# %% [markdown]
# 保证设备是GPU（CUDA）

# %%
#这一定要保证输出的是cuda
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# 下载模型到当前目录
# 下载完看一下本地目录文件位置对不对，我的在./sd-v1-5/models--sd-legacy--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592里，请把里面所有文件剪切到./sd-v1-5 (**如果出现限流，就多试几次**)

# %%
# 1. 定义下载目录（代码同目录的 sd-v1-5-download 文件夹）
# 相对路径（推荐）：./ 表示当前代码所在目录
download_dir = "./sd-v1-5"

# 2. 确保目录存在（如果不存在则自动创建）
os.makedirs(download_dir, exist_ok=True)

# 3. 加载模型时指定下载目录（核心：cache_dir 参数）
model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    cache_dir=download_dir,  # 指定模型下载到当前目录
).to("cuda")

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# model_index.json: 0.00B [00:00, ?B/s]
# D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in D:\cs\NotebookWorkspace\pytorch-study\sd-v1-5\models--sd-legacy--stable-diffusion-v1-5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# 1464

# %%
# 加载模型
model_path = "./sd-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(
    model_path,
    torch_dtype=torch.float16
)
pipe = pipe.to("cuda")

#优化效果（4G显存要用用）
from diffusers import EulerDiscreteScheduler
pipe.scheduler = EulerDiscreteScheduler.from_config(pipe.scheduler.config)

prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]

plt.figure(figsize=(8, 8))
plt.imshow(image)
plt.axis("off")
plt.show()

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1623

# %% [markdown]
# ## 学习StableDiffusion 的使用

# %% [markdown]
# ### 文生图 和 学习参数

# %% [markdown]
# prompt	               正向提示词：告诉 SD 要生成什么
# negative_prompt	       反向提示词：告诉 SD 不要生成什么
# num_inference_steps	   采样步数：反向扩散的迭代次数（UNet 去噪的次数）
# guidance_scale (CFG)   文本引导尺度：控制图像贴合提示词的程度
# height/width	       生成图像的尺寸（必须是 64 的倍数，SD 默认 512x512）
# generator	           随机数生成器：固定种子可复现相同图像
# batch_size             批量大小，一次生成的图片数量

# %% [markdown]
# 标签超市：https://tags.novelai.dev/
# github：https://github.com/wfjsw/danbooru-diffusion-prompt-builder

# %%
pipe = StableDiffusionPipeline.from_pretrained(
    model_path,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
    safety_checker=None,              # 关闭安全检查器实例（支持NSFW）
    requires_safety_checker=False,    # 禁用安全检查器依赖
).to("cuda")

#优化效果（4G显存要用用）
from diffusers import EulerDiscreteScheduler
pipe.scheduler = EulerDiscreteScheduler.from_config(pipe.scheduler.config)

#正向提示词
prompt = "garden, masterpiece, best quality"
#反向提示词
negative_prompt = "bad anatomy, missing arms, bad hands, ponytail, lowres, text, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry"
num_inference_steps = 50
guidance_scale = 7.5
num_images_per_prompt = 2
generator = torch.Generator("cuda").manual_seed(42)  # 固定种子

images = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    num_inference_steps=num_inference_steps,
    guidance_scale=guidance_scale,
    num_images_per_prompt=num_images_per_prompt,
    generator=generator  # 固定种子
).images

#画图可视化（2张图按2行1列展示）
fig, axes = plt.subplots(1, 2, figsize=(6, 6))  # 2行2列，画布大小12x12
axes = axes.flatten()                             # 把2x2的坐标轴转成一维列表，方便循环

# 循环显示每张图
for idx, img in enumerate(images):
    axes[idx].imshow(img)  # 显示图片
    axes[idx].axis("off")  # 隐藏坐标轴，更美观

# 调整子图间距，避免重叠
plt.tight_layout()
plt.show()


#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 31

# %% [markdown]
# ### 图生图

# %%
from diffusers import StableDiffusionImg2ImgPipeline

# %%
model_path = "./sd-v1-5"
pipe = StableDiffusionImg2ImgPipeline.from_pretrained(
    model_path,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
    safety_checker=None,
    requires_safety_checker=False
).to("cuda")

# 2. 加载参考图（替换为你的图片路径）
init_image = Image.open("./data/StableDiffusion/carrot_paper_cat.jpg").resize((512, 512))

# 3. 定义提示词（目标风格）
prompt = "in the middle is a cat, in the lower left corner is a pack of tissues, and in the lower right corner is a plush carrot toy, cartoon style, masterpiece, best quality"
negative_prompt = "lowres, text, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry"

# 4. 图生图（strength=0.6 控制重绘强度，0-1）
image = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    image=init_image,
    strength=0.6,  # 0.2=轻微修改，0.8=大幅重绘
    num_inference_steps=50,
    guidance_scale=7.5
).images[0]

# 5. 对比显示原图和生成图
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(12,6))
ax1.imshow(init_image)
ax1.set_title("Original Image")
ax1.axis("off")

ax2.imshow(image)
ax2.set_title("Out Image")
ax2.axis("off")

plt.show()

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# 5190

# %% [markdown]
# ### Waifu Diffusion (动漫图片:文生图)

# %% [markdown]
# 下载完记得手动移一下模型位置
# 该模型**6G**左右，运行需要**3G显存**

# %%
download_dir = "./waifu-sd-v1-4-2"
os.makedirs(download_dir, exist_ok=True)

model_id = 'hakurei/waifu-diffusion'
pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    cache_dir=download_dir, 
)

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# model_index.json: 0.00B [00:00, ?B/s]
# D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in D:\cs\NotebookWorkspace\pytorch-study\waifu-sd-v1-4-2\models--hakurei--waifu-diffusion. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# scheduler_config.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!

# %% [markdown]
# **以下两个代码一样的**

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

model_path = './waifu-sd-v1-4'
pipe = StableDiffusionPipeline.from_pretrained(
    model_path,
    torch_dtype=torch.float16,
    safety_checker=None,        # 关闭安全检查器，节省显存
    requires_safety_checker=False
).to("cuda")

# 切换高效采样器（减少步数+速度）
pipe.scheduler = EulerDiscreteScheduler.from_config(pipe.scheduler.config)

# 生图参数
prompt = "masterpiece, best quality, 1girl, green hair, sweater, looking at viewer, upper body, beanie, outdoors, watercolor, night, turtleneck"
negative_prompt = "lowres, text, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry"

# 关键参数：分辨率/步数/批量数（6G显存极限配置）
image = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    num_inference_steps=50,  
    guidance_scale=7.5,       
    width=768,              
    height=512,
    num_images_per_prompt=1,
    generator = torch.Generator("cuda").manual_seed(1919810)    #多了个可复现种子
).images[0]

# 6. 显示图片
plt.figure(figsize=(6,6))
plt.imshow(image)
plt.axis("off")
plt.show()

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1623

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

model_path = './waifu-sd-v1-4'
pipe = StableDiffusionPipeline.from_pretrained(
    model_path,
    torch_dtype=torch.float16,
    safety_checker=None,        # 关闭安全检查器，节省显存
    requires_safety_checker=False
).to("cuda")

# 切换高效采样器（减少步数+速度）
pipe.scheduler = EulerDiscreteScheduler.from_config(pipe.scheduler.config)

# 生图参数
prompt = "masterpiece, best quality, 1girl, green hair, sweater, looking at viewer, upper body, beanie, outdoors, watercolor, night, turtleneck"
negative_prompt = "lowres, text, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry"

# 关键参数：分辨率/步数/批量数（6G显存极限配置）
image = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    num_inference_steps=50,  
    guidance_scale=7.5,       
    width=768,              
    height=512,
    num_images_per_prompt=1,
).images[0]

# 6. 显示图片
plt.figure(figsize=(6,6))
plt.imshow(image)
plt.axis("off")
plt.show()

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2157

# %% [markdown]
# ### Z-Image（需要最新的transformers，python3.8不能下载，我用的python3.12）

# %% [markdown]
# 建议手动下，下载完记得手动移一下模型位置
# **该模型30.5G, 加载时需要21G显存，推理时需要14G显存和30内存**

# %%
from diffusers import ZImagePipeline

# %%
download_dir = "./z-image-sd"
os.makedirs(download_dir, exist_ok=True)

model_id = 'Tongyi-MAI/Z-Image-Turbo'
pipe = ZImagePipeline.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,   # 3090、40、50系显卡用这个
    # torch_dtype=torch.float16,      # 30系及以下用这个
    cache_dir=download_dir,  # 指定模型下载到当前目录
)

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# model_index.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in D:\cs\NotebookWorkspace\pytorch-study\z-image-sd2\models--Tongyi-MAI--Z-Image-Turbo. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# merges.txt: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# scheduler_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# (…)pytorch_model-00001-of-00003.safetensors:   0%|          | 0.00/9.97G [00:00<?, ?B/s]
# (…)pytorch_model-00002-of-00003.safetensors:   0%|          | 0.00/9.97G [00:00<?, ?B/s]
# (…)pytorch_model-00003-of-00003.safetensors:   0%|          | 0.00/4.67G [00:00<?, ?B/s]
# (…)ion_pytorch_model.safetensors.index.json: 0.00B [00:00, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# 178

# %%
from diffusers import ZImagePipeline

model_path = "./z-image-sd"
pipe = ZImagePipeline.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16,
).to("cuda")

pipe.transformer.set_attention_backend("flash")
pipe.enable_model_cpu_offload()

prompt = "masterpiece, best quality, 1girl, green hair, sweater, looking at viewer, upper body, beanie, outdoors, watercolor, night, turtleneck"
negative_prompt = "lowres, text, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry"

# 2. Generate Image
image = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    height=512,
    width=768,
    num_inference_steps= 9,  # This actually results in 8 DiT forwards
    guidance_scale=0.0,     # Guidance should be 0 for the Turbo models
    generator=torch.Generator("cuda").manual_seed(1919810),
).images[0]

# 6. 显示图片
plt.figure(figsize=(6,6))
plt.imshow(image)
plt.axis("off")
plt.show()

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Attention backends are an experimental feature and the API may be subject to change.
#   0%|          | 0/9 [00:00<?, ?it/s]
# 25269

# %%
import os
# %matplotlib inline
import torch
import matplotlib.pyplot as plt
from diffusers import StableDiffusionPipeline
import accelerate
from PIL import Image
from diffusers import ZImagePipeline

model_path = "./z-image-sd"
pipe = ZImagePipeline.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=False,
).to("cuda")

pipe.transformer.set_attention_backend("flash")
pipe.enable_model_cpu_offload()

prompt = "一个原神雷电将军女coser比耶"

# 2. Generate Image
images = pipe(
    prompt=prompt,
    height=1024,
    width=768,
    num_inference_steps= 9,  # This actually results in 8 DiT forwards
    guidance_scale=0.0,     # Guidance should be 0 for the Turbo models
    generator=torch.Generator("cuda").manual_seed(42),
    num_images_per_prompt=1 # 8g显存跑 1张图，16g就2张
).images

# 可选加速
# pipe.transformer.set_attention_backend("flash")
# pipe.enable_model_cpu_offload()

# 6. 显示图片（8g显存）
plt.figure(figsize=(8,10))
plt.imshow(images[0])
plt.axis("off")
plt.show()

# # 6.2 显示两张图片（16g显存）
# plt.figure(figsize=(16, 10))  
# plt.subplot(1, 2, 1)  
# plt.imshow(images[0])
# plt.axis("off")   
# plt.title("Image 1", fontsize=12)  
# plt.subplot(1, 2, 2) 
# plt.imshow(images[1])
# plt.axis("off")
# plt.title("Image 2", fontsize=12)  
# plt.tight_layout()
# plt.show()


#清除显存占用，重跑一遍最好重启kernel，不然内存要爆了
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# W0113 16:46:07.912000 32688 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Attention backends are an experimental feature and the API may be subject to change.
#   0%|          | 0/9 [00:00<?, ?it/s]
# 25286

# %% [markdown]
# ### lightx2v框架（需要python>=3.10，图生成视频）

# %%
import sys
print("Python版本：", sys.version)
# Out:
# Python版本： 3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]

# %%
#换了一台设备，是5080
import sys
print("Python版本：", sys.version)
# Out:
# Python版本： 3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:05:38) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# 不能用pip install lightx2v安装

# %%
# !git clone https://github.com/ModelTC/LightX2V.git
# Out:
# Cloning into 'LightX2V'...

# %%
pip install -r ./LightX2V/requirements_win.txt
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: packaging in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 1)) (25.0)
# Collecting ninja (from -r ./LightX2V/requirements_win.txt (line 2))
#   Using cached https://mirrors.aliyun.com/pypi/packages/29/45/c0adfbfb0b5895aa18cec400c535b4f7ff3e52536e0403602fc1a23f7de9/ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# Requirement already satisfied: diffusers in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 3)) (0.36.0)
# Requirement already satisfied: transformers in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 4)) (4.57.3)
# Requirement already satisfied: tokenizers in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 5)) (0.22.1)
# Requirement already satisfied: accelerate in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 6)) (1.12.0)
# Requirement already satisfied: safetensors in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 7)) (0.7.0)
# Requirement already satisfied: opencv-python in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: numpy in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 9)) (2.2.6)
# Requirement already satisfied: imageio in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 10)) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 11)) (0.6.0)
# Requirement already satisfied: einops in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 12)) (0.8.1)
# Requirement already satisfied: loguru in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 13)) (0.7.3)
# Requirement already satisfied: ftfy in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 14)) (6.3.1)
# Requirement already satisfied: gradio in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 15)) (6.2.0)
# Requirement already satisfied: aiohttp in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 16)) (3.13.2)
# Requirement already satisfied: pydantic in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 17)) (2.12.5)
# Collecting torchao (from -r ./LightX2V/requirements_win.txt (line 18))
#   Downloading https://mirrors.aliyun.com/pypi/packages/f6/3b/6b9d5618720f63dbc2e2509cd6b57aae9c0d61b738d1d2172f4d5d9efaab/torchao-0.15.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 1.1/1.1 MB 51.2 MB/s  0:00:00
# Requirement already satisfied: triton-windows in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 19)) (3.4.0.post21)
# Requirement already satisfied: prometheus_client in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 20)) (0.21.1)
# Requirement already satisfied: gguf in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from -r ./LightX2V/requirements_win.txt (line 21)) (0.17.1)
# Collecting modelscope (from -r ./LightX2V/requirements_win.txt (line 22))
#   Downloading https://mirrors.aliyun.com/pypi/packages/86/05/63f01821681b2be5d1739b4aad7b186c28d4ead2c5c99a9fc4aa53c13c19/modelscope-1.33.0-py3-none-any.whl (6.1 MB)
#      ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#      ---------------------------------------- 6.1/6.1 MB 62.2 MB/s  0:00:00
# Requirement already satisfied: importlib_metadata in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (8.7.1)
# Requirement already satisfied: filelock in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (3.20.0)
# Requirement already satisfied: httpx<1.0.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (2025.11.3)
# Requirement already satisfied: requests in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (2.32.5)
# Requirement already satisfied: Pillow in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (12.0.0)
# Requirement already satisfied: anyio in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpx<1.0.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (4.10.0)
# Requirement already satisfied: certifi in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpx<1.0.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpx<1.0.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpx<1.0.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (2025.12.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (4.15.0)
# Requirement already satisfied: psutil in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from accelerate->-r ./LightX2V/requirements_win.txt (line 6)) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from accelerate->-r ./LightX2V/requirements_win.txt (line 6)) (2.8.0+cu128)
# Requirement already satisfied: colorama>=0.3.4 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from loguru->-r ./LightX2V/requirements_win.txt (line 13)) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from loguru->-r ./LightX2V/requirements_win.txt (line 13)) (1.2.0)
# Requirement already satisfied: wcwidth in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from ftfy->-r ./LightX2V/requirements_win.txt (line 14)) (0.2.13)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.128.0)
# Requirement already satisfied: ffmpy in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (2.0.2)
# Requirement already satisfied: groovy~=0.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.1.2)
# Requirement already satisfied: jinja2<4.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (3.11.5)
# Requirement already satisfied: pandas<3.0,>=1.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (2.3.3)
# Requirement already satisfied: pydub in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.0.21)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.21.0)
# Requirement already satisfied: uvicorn>=0.14.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.40.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from pydantic->-r ./LightX2V/requirements_win.txt (line 17)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from pydantic->-r ./LightX2V/requirements_win.txt (line 17)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from pydantic->-r ./LightX2V/requirements_win.txt (line 17)) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from anyio->httpx<1.0.0->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from pandas<3.0,>=1.0->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from pandas<3.0,>=1.0->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from pandas<3.0,>=1.0->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (2025.3)
# Requirement already satisfied: click>=8.0.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from typer<1.0,>=0.12->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from typer<1.0,>=0.12->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from typer<1.0,>=0.12->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (14.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->-r ./LightX2V/requirements_win.txt (line 16)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->-r ./LightX2V/requirements_win.txt (line 16)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->-r ./LightX2V/requirements_win.txt (line 16)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->-r ./LightX2V/requirements_win.txt (line 16)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->-r ./LightX2V/requirements_win.txt (line 16)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->-r ./LightX2V/requirements_win.txt (line 16)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->-r ./LightX2V/requirements_win.txt (line 16)) (1.22.0)
# Requirement already satisfied: setuptools>=40.8.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from triton-windows->-r ./LightX2V/requirements_win.txt (line 19)) (80.9.0)
# Requirement already satisfied: urllib3>=1.26 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from modelscope->-r ./LightX2V/requirements_win.txt (line 22)) (2.6.1)
# Requirement already satisfied: six>=1.5 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from requests->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r ./LightX2V/requirements_win.txt (line 15)) (0.1.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch>=2.0.0->accelerate->-r ./LightX2V/requirements_win.txt (line 6)) (1.14.0)
# Requirement already satisfied: networkx in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch>=2.0.0->accelerate->-r ./LightX2V/requirements_win.txt (line 6)) (3.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate->-r ./LightX2V/requirements_win.txt (line 6)) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from importlib_metadata->diffusers->-r ./LightX2V/requirements_win.txt (line 3)) (3.23.0)
# Installing collected packages: torchao, ninja, modelscope
#
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    ---------------------------------------- 0/3 [torchao]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    -------------------------- ------------- 2/3 [modelscope]
#    ---------------------------------------- 3/3 [modelscope]
#
# Successfully installed modelscope-1.33.0 ninja-1.13.0 torchao-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -v ./LightX2V
# Out:
# Using pip 25.3 from D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages\pip (python 3.12)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Processing d:\cs\notebookworkspace\pytorch-study\lightx2v
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (2.3.5)
#   Link requires a different Python (3.12.12 not in: '<3.12,>=3.8'): https://mirrors.aliyun.com/pypi/packages/d6/bd/2d13a273d95f7b7d9903c906c486040b0aebb85e008f93a5dd0891f21f1f/scipy-1.10.0.tar.gz#sha256=c8b3cbc636a87a89b770c6afc999baa6bcbb01691b5ccbbc1b1791c7c0a07540 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:<3.12,>=3.8)
#   Link requires a different Python (3.12.12 not in: '<3.12,>=3.8'): https://mirrors.aliyun.com/pypi/packages/a2/ce/2592c3b550cf8f68879d4ff2159f3c689ee6f032f8fc9059022074f7bd75/scipy-1.10.0rc1.tar.gz#sha256=f094b9df619dfa67166244b70530fc12fc55961bd3a783c707a1f9d2e47242e8 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:<3.12,>=3.8)
#   Link requires a different Python (3.12.12 not in: '<3.12,>=3.8'): https://mirrors.aliyun.com/pypi/packages/6b/a3/7de758a32569e06877a6b298bdf7b529ce97a33c55deb2b1637b0162fd9d/scipy-1.10.0rc2.tar.gz#sha256=033f9188fab30a2e05a178b30e305bf811d73a3d03461395682023550dd98ed6 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:<3.12,>=3.8)
#   Link requires a different Python (3.12.12 not in: '<3.12,>=3.8'): https://mirrors.aliyun.com/pypi/packages/84/a9/2bf119f3f9cff1f376f924e39cfae18dec92a1514784046d185731301281/scipy-1.10.1.tar.gz#sha256=2cf9dfb80a7b4589ba4c40ce7588986d6d5cebc5457cad2c2880f6bc2d42f3a5 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:<3.12,>=3.8)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.10'): https://mirrors.aliyun.com/pypi/packages/99/f1/c00d6be56e1a718a3068079e3ec8ce044d7179345280f6a3f5066068af0d/scipy-1.6.2.tar.gz#sha256=e9da33e21c9bc1b92c20b5328adb13e5f193b924c9b969cd700c8908f315aa59 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.7,<3.10)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.10'): https://mirrors.aliyun.com/pypi/packages/fe/fd/8704c7b7b34cdac850485e638346025ca57c5a859934b9aa1be5399b33b7/scipy-1.6.3.tar.gz#sha256=a75b014d3294fce26852a9d04ea27b5671d86736beb34acdfc05859246260707 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.7,<3.10)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.10'): https://mirrors.aliyun.com/pypi/packages/bb/bb/944f559d554df6c9adf037aa9fc982a9706ee0e96c0d5beac701cb158900/scipy-1.7.0.tar.gz#sha256=998c5e6ea649489302de2c0bc026ed34284f531df89d2bdc8df3a0d44d165739 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.7,<3.10)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.10'): https://mirrors.aliyun.com/pypi/packages/47/33/a24aec22b7be7fdb10ec117a95e1e4099890d8bbc6646902f443fc7719d1/scipy-1.7.1.tar.gz#sha256=6b47d5fa7ea651054362561a28b1ccc8da9368a39514c1bbf6c0977a1c376764 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.7,<3.10)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.11'): https://mirrors.aliyun.com/pypi/packages/0e/23/58c4f995475a2a97cb5f4a032aedaf881ad87cd976a7180c55118d105a1d/scipy-1.7.2.tar.gz#sha256=fa2dbabaaecdb502641b0b3c00dec05fb475ae48655c66da16c9ed24eda1e711 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.11'): https://mirrors.aliyun.com/pypi/packages/61/67/1a654b96309c991762ee9bc39c363fc618076b155fe52d295211cf2536c7/scipy-1.7.3.tar.gz#sha256=ab5875facfdef77e0a47d5fd39ea178b58e60e454a4c85aa1e52fcb80db7babf (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.11'): https://mirrors.aliyun.com/pypi/packages/b4/a2/4faa34bf0cdbefd5c706625f1234987795f368eb4e97bde9d6f46860843e/scipy-1.8.0.tar.gz#sha256=31d4f2d6b724bc9a98e527b5849b8a7e589bf1ea630c33aa563eda912c9ff0bd (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.11'): https://mirrors.aliyun.com/pypi/packages/c0/ad/e3c052ed4e0027a8abef0a5e8441a044427d252d17d9aee06d56e62fc698/scipy-1.8.0rc1.tar.gz#sha256=54adf5c1197d6c3de2e131dc71660bb11d4e449aff79c8c231bd05dc6ad307eb (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.11'): https://mirrors.aliyun.com/pypi/packages/29/d2/151a54944b333e465f98804dced31dab1284f3c37b752b9cefa710b64681/scipy-1.8.0rc2.tar.gz#sha256=d73b13eb0452c178f946b4db60b27e400225df02e926609652ed67798054e77d (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.11'): https://mirrors.aliyun.com/pypi/packages/e4/26/83dd1c6378513a6241d984bda9f08c512b6e35fff13fba3acc1b3c195f02/scipy-1.8.0rc3.tar.gz#sha256=7e4f827b37275b1264102f2cc063ba17a40fb858af7a98f63b3b1be2670a34b1 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.11'): https://mirrors.aliyun.com/pypi/packages/22/78/056cc43e7737811b6f50886788a940f852773dd9804f5365952805db9648/scipy-1.8.0rc4.tar.gz#sha256=bfa5b17b108203c31388d362fe666b96c2f0aa1a094d460aab85440c22e6f22f (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.11'): https://mirrors.aliyun.com/pypi/packages/26/b5/9330f004b9a3b2b6a31f59f46f1617ce9ca15c0e7fe64288c20385a05c9d/scipy-1.8.1.tar.gz#sha256=9e3fb1b0e896f14a85aa9a28d5f755daaeeb54c897b746df7a55ccb02b340f33 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.12'): https://mirrors.aliyun.com/pypi/packages/a8/e3/4ec401f609d34162b7023a09165da491630879e4cfa2336667fe2102cd06/scipy-1.9.0.tar.gz#sha256=c0dfd7d2429452e7e94904c6a3af63cbaa3cf51b348bd9d35b42db7e9ad42791 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.12)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.12'): https://mirrors.aliyun.com/pypi/packages/87/82/8b9bf8bb8030f1eef281ad2af87cc648e06e4a4974c2b9201a57d991b12c/scipy-1.9.0rc1.tar.gz#sha256=d949aa1ad680be92b3363a60d91c17144f8f62f4236f65c2c45efed455698214 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.12)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.12'): https://mirrors.aliyun.com/pypi/packages/5a/87/27f9ee75c32138d6eaabff2b91744c97a3fdbbbdd78948372dac93e0079f/scipy-1.9.0rc2.tar.gz#sha256=83101d8bcac69c4201ff1aed52f9f41897fb0ba66e54422d2808df507126e626 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.12)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.12'): https://mirrors.aliyun.com/pypi/packages/57/72/484c38e5b814b48b41ac6432ef69077f2e7c8094925d3ce17bc3d61359b0/scipy-1.9.0rc3.tar.gz#sha256=b3b14c1d6c79c1c8edbae120c4b87c863907805e187e17a38de5f72f1735769f (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.12)
#   Link requires a different Python (3.12.12 not in: '>=3.8,<3.12'): https://mirrors.aliyun.com/pypi/packages/db/af/16906139f52bc6866c43401869ce247662739ad71afa11c6f18505eb0546/scipy-1.9.1.tar.gz#sha256=26d28c468900e6d5fdb37d2812ab46db0ccd22c63baa095057871faa3a498bc9 (from https://mirrors.aliyun.com/pypi/simple/scipy/) (requires-python:>=3.8,<3.12)
# Collecting scipy (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/c2/7f/acbd28c97e990b421af7d6d6cd416358c9c293fc958b8529e0bd5d2a2a19/scipy-1.16.3-cp312-cp312-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#      --------------- ----------------------- 14.9/38.6 MB 72.3 MB/s eta 0:00:01
#      --------------------------- ----------- 27.3/38.6 MB 66.5 MB/s eta 0:00:01
#      --------------------------------------  37.7/38.6 MB 63.1 MB/s eta 0:00:01
#      ---------------------------------------- 38.6/38.6 MB 61.3 MB/s  0:00:00
# Requirement already satisfied: torch<=2.8.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (2.8.0+cu128)
# Requirement already satisfied: torchvision<=0.23.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (0.23.0+cu128)
# Requirement already satisfied: torchaudio<=2.8.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (2.8.0+cu128)
# Requirement already satisfied: diffusers in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (0.36.0)
# Requirement already satisfied: transformers in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (4.57.3)
# Requirement already satisfied: tokenizers in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (0.22.1)
# Requirement already satisfied: tqdm in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (4.67.1)
# Requirement already satisfied: accelerate in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (1.12.0)
# Requirement already satisfied: safetensors in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (0.7.0)
# Collecting opencv-python (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fa/80/eb88edc2e2b11cd2dd2e56f1c80b5784d11d6e6b7f04a1145df64df40065/opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#      ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#      --------- ----------------------------- 10.0/39.0 MB 61.8 MB/s eta 0:00:01
#      --------------------- ----------------- 21.8/39.0 MB 52.8 MB/s eta 0:00:01
#      --------------------------------- ----- 33.3/39.0 MB 54.1 MB/s eta 0:00:01
#      ---------------------------------------- 39.0/39.0 MB 51.7 MB/s  0:00:00
# Collecting imageio (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fb/fe/301e0936b79bcab4cacc7548bf2853fc28dced0a578bab1f7ef53c9aa75b/imageio-2.37.2-py3-none-any.whl (317 kB)
# Collecting imageio-ffmpeg (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/2c/c6/fa760e12a2483469e2bf5058c5faff664acf66cadb4df2ad6205b016a73d/imageio_ffmpeg-0.6.0-py3-none-win_amd64.whl (31.2 MB)
#      ---------------------------------------- 0.0/31.2 MB ? eta -:--:--
#      -------- ------------------------------- 6.3/31.2 MB 42.8 MB/s eta 0:00:01
#      ----------------------- --------------- 19.1/31.2 MB 44.7 MB/s eta 0:00:01
#      --------------------------------------  30.9/31.2 MB 50.4 MB/s eta 0:00:01
#      ---------------------------------------- 31.2/31.2 MB 44.1 MB/s  0:00:00
# Requirement already satisfied: einops in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (0.8.1)
# Collecting loguru (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/0c/29/0348de65b8cc732daa3e33e67806420b2ae89bdce2b04af740289c5c6c8c/loguru-0.7.3-py3-none-any.whl (61 kB)
# Collecting qtorch (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/2f/aa/d1f0f20d99048f7f2b37a11f13db229594c930667ec367dfffe74f9edb70/qtorch-0.3.0-py3-none-any.whl (21 kB)
# Collecting ftfy (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ab/6e/81d47999aebc1b155f81eca4477a616a70f238a2549848c38983f3c22a82/ftfy-6.3.1-py3-none-any.whl (44 kB)
# Collecting gradio (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/24/c4/4813d4fe00298c55b355b232ca6420827c82939906aff7c396f4ac8d635c/gradio-6.2.0-py3-none-any.whl (23.0 MB)
#      ---------------------------------------- 0.0/23.0 MB ? eta -:--:--
#      ---------------- ---------------------- 10.0/23.0 MB 47.8 MB/s eta 0:00:01
#      -------------------------------- ------ 18.9/23.0 MB 44.1 MB/s eta 0:00:01
#      ---------------------------------------- 23.0/23.0 MB 44.0 MB/s  0:00:00
# Collecting aiohttp (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/0a/0d/b10ac09069973d112de6ef980c1f6bb31cb7dcd0bc363acbdad58f927873/aiohttp-3.13.2-cp312-cp312-win_amd64.whl (453 kB)
# Collecting pydantic (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/5a/87/b70ad306ebb6f9b585f114d0ac2137d792b48be34d732d60e597c2f8465a/pydantic-2.12.5-py3-none-any.whl (463 kB)
# Requirement already satisfied: prometheus-client in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (0.21.1)
# Collecting gguf (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fc/31/6a93a887617ee7deeaa602ca3d02d1c12a6cb8a742a695de5d128f5fa46a/gguf-0.17.1-py3-none-any.whl (96 kB)
# Collecting fastapi (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/5c/05/5cbb59154b093548acd0f4c7c474a118eda06da25aa75c616b72d8fcd92a/fastapi-0.128.0-py3-none-any.whl (103 kB)
# Collecting uvicorn (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/3d/d8/2083a1daa7439a66f3a48589a57d576aa117726762618f6bb09fe3798796/uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Collecting PyJWT (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/61/ad/689f02752eeec26aed679477e80e632ef1b682313be70793d798c1d5fc8f/PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from lightx2v==0.1.0) (2.32.5)
# Collecting aio-pika (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/7c/91/513971861d845d28160ecb205ae2cfaf618b16918a9cd4e0b832b5360ce7/aio_pika-9.5.8-py3-none-any.whl (54 kB)
# Collecting asyncpg>=0.27.0 (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b5/f0/f2ed1de154e15b107dc692262395b3c17fc34eafe2a78fc2115931561730/asyncpg-0.31.0-cp312-cp312-win_amd64.whl (597 kB)
#      ---------------------------------------- 0.0/597.2 kB ? eta -:--:--
#      ---------------------------------------- 597.2/597.2 kB 22.3 MB/s  0:00:00
# Collecting aioboto3>=12.0.0 (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e5/3e/e8f5b665bca646d43b916763c901e00a07e40f7746c9128bdc912a089424/aioboto3-15.5.0-py3-none-any.whl (35 kB)
# Collecting alibabacloud_dypnsapi20170525==1.2.2 (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a4/2a/933758b1a68683ff32d483e8c4426b7433985b02fad39c248b7fd1173746/alibabacloud_dypnsapi20170525-1.2.2-py3-none-any.whl (24 kB)
# Collecting redis==6.4.0 (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e8/02/89e2ed7e85db6c93dfa9e8f691c5087df4e3551ab39081a4d7c6d1f90e05/redis-6.4.0-py3-none-any.whl (279 kB)
# Collecting tos (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fe/a6/a3345e0c789c38a48cf5a1cd0dffc69f9267735bdda6c1645bfc24fbd025/tos-2.8.7.tar.gz (135 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting decord (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/6c/be/e15b5b866da452e62635a7b27513f31cb581fa2ea9cc9b768b535d62a955/decord-0.6.0-py3-none-win_amd64.whl (24.7 MB)
#      ---------------------------------------- 0.0/24.7 MB ? eta -:--:--
#      -------- ------------------------------- 5.2/24.7 MB 26.6 MB/s eta 0:00:01
#      --------------- ----------------------- 10.0/24.7 MB 27.0 MB/s eta 0:00:01
#      ---------------------- ---------------- 14.2/24.7 MB 24.0 MB/s eta 0:00:01
#      ------------------------------- ------- 20.2/24.7 MB 24.5 MB/s eta 0:00:01
#      --------------------------------------  24.1/24.7 MB 23.9 MB/s eta 0:00:01
#      ---------------------------------------- 24.7/24.7 MB 23.0 MB/s  0:00:01
# Collecting av (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/15/37/c7811eca0f318d5fd3212f7e8c3d8335f75a54907c97a89213dc580b8056/av-16.0.1-cp312-cp312-win_amd64.whl (32.3 MB)
#      ---------------------------------------- 0.0/32.3 MB ? eta -:--:--
#      ----------------- --------------------- 14.7/32.3 MB 70.7 MB/s eta 0:00:01
#      ----------------------------------- --- 29.4/32.3 MB 69.0 MB/s eta 0:00:01
#      ---------------------------------------- 32.3/32.3 MB 66.1 MB/s  0:00:00
# Collecting torchada>=0.1.10 (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a9/bb/5b556ba67e08348307d99c50a84dbf3a9e9412ed4ef536cde416943d4606/torchada-0.1.10-py3-none-any.whl (31 kB)
# Collecting alibabacloud-endpoint-util<1.0.0,>=0.0.3 (from alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/92/7d/8cc92a95c920e344835b005af6ea45a0db98763ad6ad19299d26892e6c8d/alibabacloud_endpoint_util-0.0.4.tar.gz (2.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting alibabacloud-openapi-util<1.0.0,>=0.2.1 (from alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f6/50/5f41ab550d7874c623f6e992758429802c4b52a6804db437017e5387de33/alibabacloud_openapi_util-0.2.2.tar.gz (7.2 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting alibabacloud-tea-openapi<1.0.0,>=0.3.12 (from alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/92/aa/21eae916d4befce8da5b01e22756fb47cb54fdea735ed3687ae01cb86baa/alibabacloud_tea_openapi-0.4.2-py3-none-any.whl (25 kB)
# Collecting alibabacloud-tea-util<1.0.0,>=0.3.13 (from alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/72/9e/c394b4e2104766fb28a1e44e3ed36e4c7773b4d05c868e482be99d5635c9/alibabacloud_tea_util-0.3.14-py3-none-any.whl (6.7 kB)
# Collecting cryptography>=3.0.0 (from alibabacloud-openapi-util<1.0.0,>=0.2.1->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/7e/bf/80fbf45253ea585a1e492a6a17efcb93467701fa79e71550a430c5e60df0/cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 3.5/3.5 MB 69.2 MB/s  0:00:00
# Collecting alibabacloud-credentials<2.0.0,>=1.0.2 (from alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fb/96/71fecdfd1c91a12072bd1eb143ef289eb72ddfa5cfa45306afbc6a7bd3ca/alibabacloud_credentials-1.0.4-py3-none-any.whl (48 kB)
# Collecting alibabacloud-gateway-spi<1.0.0,>=0.0.2 (from alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ab/98/d7111245f17935bf72ee9bea60bbbeff2bc42cdfe24d2544db52bc517e1a/alibabacloud_gateway_spi-0.0.3.tar.gz (4.2 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cryptography>=3.0.0 (from alibabacloud-openapi-util<1.0.0,>=0.2.1->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/c9/ad/51f212198681ea7b0deaaf8846ee10af99fba4e894f67b353524eab2bbe5/cryptography-44.0.3-cp39-abi3-win_amd64.whl (3.2 MB)
#      ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#      ---------------------------------------- 3.2/3.2 MB 47.6 MB/s  0:00:00
# Collecting darabonba-core<2.0.0,>=1.0.3 (from alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/66/d3/a7daaee544c904548e665829b51a9fa2572acb82c73ad787a8ff90273002/darabonba_core-1.0.5-py3-none-any.whl (24 kB)
# Collecting APScheduler<4.0.0,>=3.10.0 (from alibabacloud-credentials<2.0.0,>=1.0.2->alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9f/64/2e54428beba8d9992aa478bb8f6de9e4ecaa5f8f513bcfd567ed7fb0262d/apscheduler-3.11.2-py3-none-any.whl (64 kB)
# Collecting aiofiles<25.0.0,>=22.1.0 (from alibabacloud-credentials<2.0.0,>=1.0.2->alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a5/45/30bb92d442636f570cb5651bc661f52b610e2eec3f891a5dc3a4c3667db0/aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Collecting alibabacloud-tea>=0.4.0 (from alibabacloud-credentials<2.0.0,>=1.0.2->alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9a/7d/b22cb9a0d4f396ee0f3f9d7f26b76b9ed93d4101add7867a2c87ed2534f5/alibabacloud-tea-0.4.3.tar.gz (8.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting alibabacloud-credentials-api<2.0.0,>=1.0.0 (from alibabacloud-credentials<2.0.0,>=1.0.2->alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a0/87/1d7019d23891897cb076b2f7e3c81ab3c2ba91de3bb067196f675d60d34c/alibabacloud-credentials-api-1.0.0.tar.gz (2.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tzlocal>=3.0 (from APScheduler<4.0.0,>=3.10.0->alibabacloud-credentials<2.0.0,>=1.0.2->alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/c2/14/e2a54fabd4f08cd7af1c07030603c3356b74da07f7cc056e600436edfa17/tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: cffi>=1.12 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from cryptography>=3.0.0->alibabacloud-openapi-util<1.0.0,>=0.2.1->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0) (2.0.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/0f/15/5bf3b99495fb160b63f95972b81750f18f7f4e02ad051373b669d17d44f2/aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fb/76/641ae371508676492379f16e2fa48f4e2c11741bd63c48be4b12a6b09cba/aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiohttp->lightx2v==0.1.0) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b8/af/38e51a553dd66eb064cdf193841f16f077585d4d28394c2fa6235cb41765/frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/46/e2/348cd32faad84eaf1d20cce80e2bb0ef8d312c55bca1f7fa9865e7770aaf/multidict-6.7.0-cp312-cp312-win_amd64.whl (46 kB)
# Collecting propcache>=0.2.0 (from aiohttp->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/54/09/d19cff2a5aaac632ec8fc03737b223597b1e347416934c1b3a7df079784c/propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/c8/9a/6ad1a9b37c2f72874f93e691b2e7ecb6137fb2b899983125db4204e47575/yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from requests->lightx2v==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from requests->lightx2v==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from requests->lightx2v==0.1.0) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from requests->lightx2v==0.1.0) (2025.11.12)
# Requirement already satisfied: filelock in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch<=2.8.0->lightx2v==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch<=2.8.0->lightx2v==0.1.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch<=2.8.0->lightx2v==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch<=2.8.0->lightx2v==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch<=2.8.0->lightx2v==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch<=2.8.0->lightx2v==0.1.0) (2025.12.0)
# Requirement already satisfied: setuptools in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torch<=2.8.0->lightx2v==0.1.0) (80.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from torchvision<=0.23.0->lightx2v==0.1.0) (12.0.0)
# Collecting aiobotocore==2.25.1 (from aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/95/2a/d275ec4ce5cd0096665043995a7d76f5d0524853c76a3d04656de49f8808/aiobotocore-2.25.1-py3-none-any.whl (86 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/10/a1/510b0a7fadc6f43a6ce50152e69dbd86415240835868bb0bd9b5b88b1e06/aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Collecting botocore<1.40.62,>=1.40.46 (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/38/c5/f6ce561004db45f0b847c2cd9b19c67c6bf348a82018a48cb718be6b58b0/botocore-1.40.61-py3-none-any.whl (14.1 MB)
#      ---------------------------------------- 0.0/14.1 MB ? eta -:--:--
#      ------------------- -------------------- 6.8/14.1 MB 34.9 MB/s eta 0:00:01
#      ------------------------------------ -- 13.1/14.1 MB 31.6 MB/s eta 0:00:01
#      ---------------------------------------- 14.1/14.1 MB 29.4 MB/s  0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0) (2.9.0.post0)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/28/de/49493f962bd3c586ab4b88066e967aa2e0703d6ef2c43aa28cb83bf7b507/wrapt-1.17.3-cp312-cp312-win_amd64.whl (38 kB)
# Collecting boto3<1.40.62,>=1.40.46 (from aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/61/24/3bf865b07d15fea85b63504856e137029b6acbc73762496064219cdb265d/boto3-1.40.61-py3-none-any.whl (139 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3<1.40.62,>=1.40.46->aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/48/f0/ae7ca09223a81a1d890b2557186ea015f6e0502e9b8cb8e1813f1d8cfa4e/s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Requirement already satisfied: six>=1.5 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3>=12.0.0->lightx2v==0.1.0) (1.17.0)
# Requirement already satisfied: pycparser in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from cffi>=1.12->cryptography>=3.0.0->alibabacloud-openapi-util<1.0.0,>=0.2.1->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0) (2.23)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from sympy>=1.13.3->torch<=2.8.0->lightx2v==0.1.0) (1.3.0)
# Requirement already satisfied: tzdata in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from tzlocal>=3.0->APScheduler<4.0.0,>=3.10.0->alibabacloud-credentials<2.0.0,>=1.0.2->alibabacloud-tea-openapi<1.0.0,>=0.3.12->alibabacloud_dypnsapi20170525==1.2.2->lightx2v==0.1.0) (2025.3)
# Requirement already satisfied: packaging>=20.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from accelerate->lightx2v==0.1.0) (25.0)
# Requirement already satisfied: psutil in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from accelerate->lightx2v==0.1.0) (7.0.0)
# Requirement already satisfied: pyyaml in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from accelerate->lightx2v==0.1.0) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from accelerate->lightx2v==0.1.0) (0.36.0)
# Requirement already satisfied: colorama in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from tqdm->lightx2v==0.1.0) (0.4.6)
# Collecting aiormq<7.0,>=6.8 (from aio-pika->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/52/ec/763b13f148f3760c1562cedb593feaffbae177eeece61af5d0ace7b72a3e/aiormq-6.9.2-py3-none-any.whl (31 kB)
# Collecting pamqp==3.3.0 (from aiormq<7.0,>=6.8->aio-pika->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ac/8d/c1e93296e109a320e508e38118cf7d1fc2a4d1c2ec64de78565b3c445eb5/pamqp-3.3.0-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: importlib_metadata in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->lightx2v==0.1.0) (8.7.1)
# Requirement already satisfied: httpx<1.0.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->lightx2v==0.1.0) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from diffusers->lightx2v==0.1.0) (2025.11.3)
# Requirement already satisfied: anyio in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpx<1.0.0->diffusers->lightx2v==0.1.0) (4.10.0)
# Requirement already satisfied: httpcore==1.* in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpx<1.0.0->diffusers->lightx2v==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers->lightx2v==0.1.0) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from anyio->httpx<1.0.0->diffusers->lightx2v==0.1.0) (1.3.1)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d9/52/1064f510b141bd54025f9b55105e26d1fa970b9be67ad766380a3c9b74b0/starlette-0.50.0-py3-none-any.whl (74 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/1e/d3/26bf1008eb3d2daa8ef4cacc7f3bfdc11818d111f7e2d0201bc6e3b49d45/annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5 (from pydantic->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/86/45/00173a033c801cacf67c190fef088789394feaf88a98a7035b0e40d53dc9/pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ---------------------------------------- 2.0/2.0 MB 27.9 MB/s  0:00:00
# Collecting typing-inspection>=0.4.2 (from pydantic->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/dc/9b/47798a6c91d8bdb567fe2698fe81e0c6b7cb7ef4d13da4114b41d239f65d/typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: wcwidth in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from ftfy->lightx2v==0.1.0) (0.2.13)
# Collecting brotli>=1.1.0 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/1c/4e/bc1dcac9498859d5e353c9b153627a3752868a9d5f05ce8dedd81a2354ab/brotli-1.2.0-cp312-cp312-win_amd64.whl (369 kB)
# Collecting ffmpy (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/55/56/dd3669eccebb6d8ac81e624542ebd53fe6f08e1b8f2f8d50aeb7e3b83f99/ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Collecting gradio-client==2.0.2 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a7/a2/a3497afea984202f481de3464b3bfbcb3de1cd83cbbf3714933d40dd7106/gradio_client-2.0.2-py3-none-any.whl (55 kB)
# Collecting groovy~=0.1 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/28/27/3d6dcadc8a3214d8522c1e7f6a19554e33659be44546d44a2f7572ac7d2a/groovy-0.1.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->lightx2v==0.1.0) (3.0.2)
# Collecting orjson~=3.0 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d4/fb/f05646c43d5450492cb387de5549f6de90a71001682c17882d9f66476af5/orjson-3.11.5-cp312-cp312-win_amd64.whl (133 kB)
# Requirement already satisfied: pandas<3.0,>=1.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from gradio->lightx2v==0.1.0) (2.3.3)
# Collecting pydub (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a6/53/d78dc063216e62fc55f6b2eebb447f6a4b0a59f55c8406376f76bf959b08/pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart>=0.0.18 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/aa/76/03af049af4dcee5d27442f71b6924f01f3efb5d2bd34f23fcd563f2cc5f5/python_multipart-0.0.21-py3-none-any.whl (24 kB)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/2e/a3/0f0b7d78e2f1eb9e8e1afbff1d2bff8d60144aee17aca51c065b516743dd/safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Collecting semantic-version~=2.0 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/6a/23/8146aad7d88f4fcb3a6218f41a60f6c2d4e3a72de72da1825dc7c8f7877c/semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/bd/75/8539d011f6be8e29f339c42e633aae3cb73bffa95dd0f9adec09b9c58e85/tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Collecting typer<1.0,>=0.12 (from gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e1/e4/5ebc1899d31d2b1601b32d21cfb4bba022ae6fce323d365f0448031b1660/typer-0.21.0-py3-none-any.whl (47 kB)
# Requirement already satisfied: pytz>=2020.1 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from pandas<3.0,>=1.0->gradio->lightx2v==0.1.0) (2025.2)
# Requirement already satisfied: click>=8.0.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from typer<1.0,>=0.12->gradio->lightx2v==0.1.0) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from typer<1.0,>=0.12->gradio->lightx2v==0.1.0) (1.5.4)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/25/7a/b0178788f8dc6cafce37a212c99565fa1fe7872c70c6c9c1e1a372d9d88f/rich-14.2.0-py3-none-any.whl (243 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/94/54/e7d793b573f298e1c9013b8c4dade17d481164aa517d1d7148619c2cedbf/markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->lightx2v==0.1.0) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b3/38/89ba8ad64ae25be8de66a6d463314cf1eb366222074cfda9ee839c56a4b4/mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: zipp>=3.20 in d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages (from importlib_metadata->diffusers->lightx2v==0.1.0) (3.23.0)
# Collecting win32-setctime>=1.0.0 (from loguru->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e1/07/c6fe3ad3e685340704d314d765b7912993bcb8dc198f0e7a89382d37974b/win32_setctime-1.2.0-py3-none-any.whl (4.1 kB)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.11'): https://mirrors.aliyun.com/pypi/packages/3a/be/650f9c091ef71cb01d735775d554e068752d3ff63d7943b26316dc401749/numpy-1.21.2.zip#sha256=423216d8afc5923b15df86037c6053bf030d15cc9e3224206ef868c2d63dd6dc (from https://mirrors.aliyun.com/pypi/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.11'): https://mirrors.aliyun.com/pypi/packages/5f/d6/ad58ded26556eaeaa8c971e08b6466f17c4ac4d786cd3d800e26ce59cc01/numpy-1.21.3.zip#sha256=63571bb7897a584ca3249c86dd01c10bcb5fe4296e3568b2e9c1a55356b6410e (from https://mirrors.aliyun.com/pypi/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.11'): https://mirrors.aliyun.com/pypi/packages/fb/48/b0708ebd7718a8933f0d3937513ef8ef2f4f04529f1f66ca86d873043921/numpy-1.21.4.zip#sha256=e6c76a87633aa3fa16614b61ccedfae45b91df2767cf097aa9c933932a7ed1e0 (from https://mirrors.aliyun.com/pypi/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.11'): https://mirrors.aliyun.com/pypi/packages/c2/a8/a924a09492bdfee8c2ec3094d0a13f2799800b4fdc9c890738aeeb12c72e/numpy-1.21.5.zip#sha256=6a5928bc6241264dce5ed509e66f33676fc97f464e7a919edc672fb5532221ee (from https://mirrors.aliyun.com/pypi/simple/numpy/) (requires-python:>=3.7,<3.11)
#   Link requires a different Python (3.12.12 not in: '>=3.7,<3.11'): https://mirrors.aliyun.com/pypi/packages/45/b7/de7b8e67f2232c26af57c205aaad29fe17754f793404f59c8a730c7a191a/numpy-1.21.6.zip#sha256=ecb55251139706669fdec2ff073c98ef8e9a84473e51e716211b41aa0f18e656 (from https://mirrors.aliyun.com/pypi/simple/numpy/) (requires-python:>=3.7,<3.11)
# Collecting numpy (from lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/36/fa/8c9210162ca1b88529ab76b41ba02d433fd54fecaf6feb70ef9f124683f1/numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
#      ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#      ---------------------------------------- 12.6/12.6 MB 66.1 MB/s  0:00:00
# Collecting Deprecated<2.0.0,>=1.2.13 (from tos->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/84/d0/205d54408c08b13550c733c4b85429e7ead111c7f0014309637425520a9a/deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Collecting crcmod>=1.7 (from tos->lightx2v==0.1.0)
#   Downloading https://mirrors.aliyun.com/pypi/packages/6b/b0/e595ce2a2527e169c3bcd6c33d2473c1918e0b7f6826a043ca1245dd4e5b/crcmod-1.7.tar.gz (89 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: lightx2v, alibabacloud-endpoint-util, alibabacloud-openapi-util, alibabacloud-credentials-api, alibabacloud-gateway-spi, alibabacloud-tea, tos, crcmod
#   Building wheel for lightx2v (pyproject.toml): started
#   Building wheel for lightx2v (pyproject.toml): finished with status 'done'
#   Created wheel for lightx2v: filename=lightx2v-0.1.0-py3-none-any.whl size=603636 sha256=ef730a5d1db2c4a52f5453812c6bb3f1c2a292960d6f2d3bf1d0394fe6d98469
#   Stored in directory: C:\Users\weiss\AppData\Local\Temp\pip-ephem-wheel-cache-1h_7khm5\wheels\4a\41\64\ef3787566cfbc646943a22c1aa0b03dfa7632309b016f17d31
#   Building wheel for alibabacloud-endpoint-util (pyproject.toml): started
#   Building wheel for alibabacloud-endpoint-util (pyproject.toml): finished with status 'done'
#   Created wheel for alibabacloud-endpoint-util: filename=alibabacloud_endpoint_util-0.0.4-py3-none-any.whl size=2723 sha256=a82a0bf2be8536500debc47f06cd7f55bb8e548c6a73759d945562bbeca89272
#   Stored in directory: c:\users\weiss\appdata\local\pip\cache\wheels\bb\01\db\aaf87f3ce79cd18bbef046aceb7c915f23f936027a97365be6
#   Building wheel for alibabacloud-openapi-util (pyproject.toml): started
#   Building wheel for alibabacloud-openapi-util (pyproject.toml): finished with status 'done'
#   Created wheel for alibabacloud-openapi-util: filename=alibabacloud_openapi_util-0.2.2-py3-none-any.whl size=7439 sha256=61789c99a5de2a152536ddf4a65b2db15d63ff5ffef02c9cde44b922e6e42ef1
#   Stored in directory: c:\users\weiss\appdata\local\pip\cache\wheels\29\08\32\c1b8c907de74cebdb6d2be72efe78f004c4d6658308c9d3265
#   Building wheel for alibabacloud-credentials-api (pyproject.toml): started
#   Building wheel for alibabacloud-credentials-api (pyproject.toml): finished with status 'done'
#   Created wheel for alibabacloud-credentials-api: filename=alibabacloud_credentials_api-1.0.0-py3-none-any.whl size=2304 sha256=f2d2c1b532ffac9ccd7b3f548b559aad6f0afdccf54c7279ac7521fab5da56a5
#   Stored in directory: c:\users\weiss\appdata\local\pip\cache\wheels\fa\b6\6a\0e62e3c99c1995edbfde85e0c5e8a30874a7e1e00903856b5b
#   Building wheel for alibabacloud-gateway-spi (pyproject.toml): started
#   Building wheel for alibabacloud-gateway-spi (pyproject.toml): finished with status 'done'
#   Created wheel for alibabacloud-gateway-spi: filename=alibabacloud_gateway_spi-0.0.3-py3-none-any.whl size=4365 sha256=2fb6e6f0197067ae5f69cb307a14b6466f27202e5da7c6aebb6da5c3129805fd
#   Stored in directory: c:\users\weiss\appdata\local\pip\cache\wheels\fd\1b\8b\bf00e8a27393c300b40169fdb76eadab30ea1196ab91b9dc9c
#   Building wheel for alibabacloud-tea (pyproject.toml): started
#   Building wheel for alibabacloud-tea (pyproject.toml): finished with status 'done'
#   Created wheel for alibabacloud-tea: filename=alibabacloud_tea-0.4.3-py3-none-any.whl size=8464 sha256=a0ada945d74dafed2e88f64fafc79262ee5c99d932c6ce8dcc305860c2917b7e
#   Stored in directory: c:\users\weiss\appdata\local\pip\cache\wheels\2d\bf\7e\38fa5077aa89c7c0b67a0c92db83c889076dca582315dcb8ae
#   Building wheel for tos (pyproject.toml): started
#   Building wheel for tos (pyproject.toml): finished with status 'done'
#   Created wheel for tos: filename=tos-2.8.7-py3-none-any.whl size=105248 sha256=d0562512a18ea52e35574b6e205218aa33a5007bff6d08fddb998cb7b4891de4
#   Stored in directory: c:\users\weiss\appdata\local\pip\cache\wheels\21\8e\82\1a1af0e088d52dad93bba01f0e3885e22c011066df1e116e73
#   Building wheel for crcmod (pyproject.toml): started
#   Building wheel for crcmod (pyproject.toml): finished with status 'done'
#   Created wheel for crcmod: filename=crcmod-1.7-cp312-cp312-win_amd64.whl size=25427 sha256=6df275c687d0ea0178fcd6dcc83ce54ce1eacf6ce3bbbf49d5d5eb559036ca17
#   Stored in directory: c:\users\weiss\appdata\local\pip\cache\wheels\9c\e7\89\c5f7142327aaa5ab362c138b424b566a272bb0d1d943e7ef4a
# Successfully built lightx2v alibabacloud-endpoint-util alibabacloud-openapi-util alibabacloud-credentials-api alibabacloud-gateway-spi alibabacloud-tea tos crcmod
# Installing collected packages: pydub, crcmod, brotli, alibabacloud-endpoint-util, wrapt, win32-setctime, tzlocal, typing-inspection, tomlkit, semantic-version, redis, python-multipart, PyJWT, pydantic-core, propcache, pamqp, orjson, numpy, multidict, mdurl, jmespath, imageio-ffmpeg, groovy, ftfy, frozenlist, ffmpy, av, asyncpg, annotated-types, annotated-doc, alibabacloud-credentials-api, aioitertools, aiohappyeyeballs, aiofiles, yarl, uvicorn, starlette, scipy, pydantic, opencv-python, markdown-it-py, loguru, imageio, gguf, Deprecated, decord, cryptography, botocore, APScheduler, aiosignal, tos, torchada, safehttpx, s3transfer, rich, qtorch, gradio-client, fastapi, aiormq, aiohttp, typer, boto3, alibabacloud-tea, aiobotocore, aio-pika, gradio, darabonba-core, alibabacloud-tea-util, alibabacloud-credentials, alibabacloud-openapi-util, alibabacloud-gateway-spi, aioboto3, alibabacloud-tea-openapi, alibabacloud_dypnsapi20170525, lightx2v
#
#    -- -------------------------------------  5/75 [win32-setctime]
#    ---- -----------------------------------  9/75 [semantic-version]
#    ----- ---------------------------------- 10/75 [redis]
#    ----- ---------------------------------- 10/75 [redis]
#    ----- ---------------------------------- 11/75 [python-multipart]
#    ------- -------------------------------- 14/75 [propcache]
#   Attempting uninstall: numpy
#    ------- -------------------------------- 14/75 [propcache]
#     Found existing installation: numpy 2.3.5
#    ------- -------------------------------- 14/75 [propcache]
#    --------- ------------------------------ 17/75 [numpy]
#     Uninstalling numpy-2.3.5:
#    --------- ------------------------------ 17/75 [numpy]
#       Removing file or directory d:\cs\anaconda3-24-10\envs\pytorch-study\lib\site-packages\numpy-2.3.5.dist-info\
#    --------- ------------------------------ 17/75 [numpy]
# ...
#   running install_scripts
#   creating build\bdist.win-amd64\wheel\alibabacloud_openapi_util-0.2.2.dist-info\WHEEL
#   creating 'c:\users\weiss\appdata\local\pip\cache\wheels\29\08\32\c1b8c907de74cebdb6d2be72efe78f004c4d6658308c9d3265\tmpxvpe6j9y\.tmp-mjae8p2n\alibabacloud_openapi_util-0.2.2-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
#   adding 'alibabacloud_openapi_util/__init__.py'
#   adding 'alibabacloud_openapi_util/client.py'
#   adding 'alibabacloud_openapi_util/sm3.py'
#   adding 'alibabacloud_openapi_util-0.2.2.dist-info/METADATA'
#   adding 'alibabacloud_openapi_util-0.2.2.dist-info/WHEEL'
#   adding 'alibabacloud_openapi_util-0.2.2.dist-info/top_level.txt'
#   adding 'alibabacloud_openapi_util-0.2.2.dist-info/RECORD'
#   removing build\bdist.win-amd64\wheel
#   Running command Building wheel for alibabacloud-credentials-api (pyproject.toml)
#   Warning: 'classifiers' should be a list, got type 'tuple'
#   C:\Users\weiss\AppData\Local\Temp\pip-build-env-66a4eztd\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: Apache Software License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib\alibabacloud_credentials_api
#   copying alibabacloud_credentials_api\models.py -> build\lib\alibabacloud_credentials_api
#   copying alibabacloud_credentials_api\__init__.py -> build\lib\alibabacloud_credentials_api
#   running egg_info
#   writing alibabacloud_credentials_api.egg-info\PKG-INFO
#   writing dependency_links to alibabacloud_credentials_api.egg-info\dependency_links.txt
#   writing top-level names to alibabacloud_credentials_api.egg-info\top_level.txt
#   reading manifest file 'alibabacloud_credentials_api.egg-info\SOURCES.txt'
#   writing manifest file 'alibabacloud_credentials_api.egg-info\SOURCES.txt'
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\alibabacloud_credentials_api
#   copying build\lib\alibabacloud_credentials_api\models.py -> build\bdist.win-amd64\wheel\.\alibabacloud_credentials_api
#   copying build\lib\alibabacloud_credentials_api\__init__.py -> build\bdist.win-amd64\wheel\.\alibabacloud_credentials_api
#   running install_egg_info
#   Copying alibabacloud_credentials_api.egg-info to build\bdist.win-amd64\wheel\.\alibabacloud_credentials_api-1.0.0-py3.12.egg-info
#   running install_scripts
#   creating build\bdist.win-amd64\wheel\alibabacloud_credentials_api-1.0.0.dist-info\WHEEL
#   creating 'c:\users\weiss\appdata\local\pip\cache\wheels\fa\b6\6a\0e62e3c99c1995edbfde85e0c5e8a30874a7e1e00903856b5b\tmpnxwg64gc\.tmp-t7e2ppbt\alibabacloud_credentials_api-1.0.0-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
#   adding 'alibabacloud_credentials_api/__init__.py'
#   adding 'alibabacloud_credentials_api/models.py'
#   adding 'alibabacloud_credentials_api-1.0.0.dist-info/METADATA'
#   adding 'alibabacloud_credentials_api-1.0.0.dist-info/WHEEL'
#   adding 'alibabacloud_credentials_api-1.0.0.dist-info/top_level.txt'
#   adding 'alibabacloud_credentials_api-1.0.0.dist-info/RECORD'
#   removing build\bdist.win-amd64\wheel
#   Running command Building wheel for alibabacloud-gateway-spi (pyproject.toml)
#   Warning: 'classifiers' should be a list, got type 'tuple'
#   C:\Users\weiss\AppData\Local\Temp\pip-build-env-3ypl30dj\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: Apache Software License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib\alibabacloud_gateway_spi
#   copying alibabacloud_gateway_spi\client.py -> build\lib\alibabacloud_gateway_spi
#   copying alibabacloud_gateway_spi\models.py -> build\lib\alibabacloud_gateway_spi
#   copying alibabacloud_gateway_spi\__init__.py -> build\lib\alibabacloud_gateway_spi
#   running egg_info
#   writing alibabacloud_gateway_spi.egg-info\PKG-INFO
#   writing dependency_links to alibabacloud_gateway_spi.egg-info\dependency_links.txt
#   writing requirements to alibabacloud_gateway_spi.egg-info\requires.txt
#   writing top-level names to alibabacloud_gateway_spi.egg-info\top_level.txt
#   reading manifest file 'alibabacloud_gateway_spi.egg-info\SOURCES.txt'
#   writing manifest file 'alibabacloud_gateway_spi.egg-info\SOURCES.txt'
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\alibabacloud_gateway_spi
#   copying build\lib\alibabacloud_gateway_spi\client.py -> build\bdist.win-amd64\wheel\.\alibabacloud_gateway_spi
#   copying build\lib\alibabacloud_gateway_spi\models.py -> build\bdist.win-amd64\wheel\.\alibabacloud_gateway_spi
#   copying build\lib\alibabacloud_gateway_spi\__init__.py -> build\bdist.win-amd64\wheel\.\alibabacloud_gateway_spi
#   running install_egg_info
#   Copying alibabacloud_gateway_spi.egg-info to build\bdist.win-amd64\wheel\.\alibabacloud_gateway_spi-0.0.3-py3.12.egg-info
#   running install_scripts
#   creating build\bdist.win-amd64\wheel\alibabacloud_gateway_spi-0.0.3.dist-info\WHEEL
#   creating 'c:\users\weiss\appdata\local\pip\cache\wheels\fd\1b\8b\bf00e8a27393c300b40169fdb76eadab30ea1196ab91b9dc9c\tmprfw91_8m\.tmp-z6wifogd\alibabacloud_gateway_spi-0.0.3-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
#   adding 'alibabacloud_gateway_spi/__init__.py'
#   adding 'alibabacloud_gateway_spi/client.py'
#   adding 'alibabacloud_gateway_spi/models.py'
#   adding 'alibabacloud_gateway_spi-0.0.3.dist-info/METADATA'
#   adding 'alibabacloud_gateway_spi-0.0.3.dist-info/WHEEL'
#   adding 'alibabacloud_gateway_spi-0.0.3.dist-info/top_level.txt'
#   adding 'alibabacloud_gateway_spi-0.0.3.dist-info/RECORD'
#   removing build\bdist.win-amd64\wheel
#   Running command Building wheel for alibabacloud-tea (pyproject.toml)
#   Warning: 'classifiers' should be a list, got type 'tuple'
#   C:\Users\weiss\AppData\Local\Temp\pip-build-env-dv3tqtue\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: Apache Software License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib\Tea
#   copying Tea\core.py -> build\lib\Tea
#   copying Tea\decorators.py -> build\lib\Tea
#   copying Tea\exceptions.py -> build\lib\Tea
#   copying Tea\model.py -> build\lib\Tea
#   copying Tea\request.py -> build\lib\Tea
#   copying Tea\response.py -> build\lib\Tea
#   copying Tea\stream.py -> build\lib\Tea
#   copying Tea\__init__.py -> build\lib\Tea
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\Tea
#   copying build\lib\Tea\core.py -> build\bdist.win-amd64\wheel\.\Tea
#   copying build\lib\Tea\decorators.py -> build\bdist.win-amd64\wheel\.\Tea
#   copying build\lib\Tea\exceptions.py -> build\bdist.win-amd64\wheel\.\Tea
#   copying build\lib\Tea\model.py -> build\bdist.win-amd64\wheel\.\Tea
#   copying build\lib\Tea\request.py -> build\bdist.win-amd64\wheel\.\Tea
#   copying build\lib\Tea\response.py -> build\bdist.win-amd64\wheel\.\Tea
#   copying build\lib\Tea\stream.py -> build\bdist.win-amd64\wheel\.\Tea
#   copying build\lib\Tea\__init__.py -> build\bdist.win-amd64\wheel\.\Tea
#   running install_egg_info
#   running egg_info
#   writing alibabacloud_tea.egg-info\PKG-INFO
#   writing dependency_links to alibabacloud_tea.egg-info\dependency_links.txt
#   writing requirements to alibabacloud_tea.egg-info\requires.txt
#   writing top-level names to alibabacloud_tea.egg-info\top_level.txt
#   reading manifest file 'alibabacloud_tea.egg-info\SOURCES.txt'
#   writing manifest file 'alibabacloud_tea.egg-info\SOURCES.txt'
#   Copying alibabacloud_tea.egg-info to build\bdist.win-amd64\wheel\.\alibabacloud_tea-0.4.3-py3.12.egg-info
#   running install_scripts
#   creating build\bdist.win-amd64\wheel\alibabacloud_tea-0.4.3.dist-info\WHEEL
#   creating 'c:\users\weiss\appdata\local\pip\cache\wheels\2d\bf\7e\38fa5077aa89c7c0b67a0c92db83c889076dca582315dcb8ae\tmpuj_xlbvi\.tmp-0equv7b7\alibabacloud_tea-0.4.3-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
#   adding 'Tea/__init__.py'
#   adding 'Tea/core.py'
#   adding 'Tea/decorators.py'
#   adding 'Tea/exceptions.py'
#   adding 'Tea/model.py'
#   adding 'Tea/request.py'
#   adding 'Tea/response.py'
#   adding 'Tea/stream.py'
#   adding 'alibabacloud_tea-0.4.3.dist-info/METADATA'
#   adding 'alibabacloud_tea-0.4.3.dist-info/WHEEL'
#   adding 'alibabacloud_tea-0.4.3.dist-info/top_level.txt'
#   adding 'alibabacloud_tea-0.4.3.dist-info/RECORD'
#   removing build\bdist.win-amd64\wheel
#   Running command Building wheel for tos (pyproject.toml)
#   C:\Users\weiss\AppData\Local\Temp\pip-build-env-l3ozlodv\overlay\Lib\site-packages\setuptools\dist.py:332: InformationOnly: Normalizing 'v2.8.7' to '2.8.7'
#     self.metadata.version = self._normalize_version(self.metadata.version)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib\tos
#   copying tos\auth.py -> build\lib\tos
#   copying tos\checkpoint.py -> build\lib\tos
#   copying tos\client.py -> build\lib\tos
#   copying tos\clientv2.py -> build\lib\tos
#   copying tos\consts.py -> build\lib\tos
#   copying tos\convertor.py -> build\lib\tos
#   copying tos\credential.py -> build\lib\tos
#   copying tos\enum.py -> build\lib\tos
#   copying tos\exceptions.py -> build\lib\tos
#   copying tos\http.py -> build\lib\tos
#   copying tos\json_utils.py -> build\lib\tos
#   copying tos\log.py -> build\lib\tos
#   copying tos\mine_type.py -> build\lib\tos
#   copying tos\models.py -> build\lib\tos
#   copying tos\models2.py -> build\lib\tos
#   copying tos\safe_map.py -> build\lib\tos
#   copying tos\thread_ctx.py -> build\lib\tos
#   copying tos\utils.py -> build\lib\tos
#   copying tos\__init__.py -> build\lib\tos
#   copying tos\__version__.py -> build\lib\tos
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\tos
#   copying build\lib\tos\auth.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\checkpoint.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\client.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\clientv2.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\consts.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\convertor.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\credential.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\enum.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\exceptions.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\http.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\json_utils.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\log.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\mine_type.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\models.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\models2.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\safe_map.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\thread_ctx.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\utils.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\__init__.py -> build\bdist.win-amd64\wheel\.\tos
#   copying build\lib\tos\__version__.py -> build\bdist.win-amd64\wheel\.\tos
#   running install_egg_info
#   running egg_info
#   writing tos.egg-info\PKG-INFO
#   writing dependency_links to tos.egg-info\dependency_links.txt
#   writing requirements to tos.egg-info\requires.txt
#   writing top-level names to tos.egg-info\top_level.txt
#   reading manifest file 'tos.egg-info\SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file 'tos.egg-info\SOURCES.txt'
#   Copying tos.egg-info to build\bdist.win-amd64\wheel\.\tos-2.8.7-py3.12.egg-info
#   running install_scripts
#   creating build\bdist.win-amd64\wheel\tos-2.8.7.dist-info\WHEEL
#   creating 'c:\users\weiss\appdata\local\pip\cache\wheels\21\8e\82\1a1af0e088d52dad93bba01f0e3885e22c011066df1e116e73\tmpl_r7xmyb\.tmp-5l5krhmf\tos-2.8.7-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
#   adding 'tos/__init__.py'
#   adding 'tos/__version__.py'
#   adding 'tos/auth.py'
#   adding 'tos/checkpoint.py'
#   adding 'tos/client.py'
#   adding 'tos/clientv2.py'
#   adding 'tos/consts.py'
#   adding 'tos/convertor.py'
#   adding 'tos/credential.py'
#   adding 'tos/enum.py'
#   adding 'tos/exceptions.py'
#   adding 'tos/http.py'
#   adding 'tos/json_utils.py'
#   adding 'tos/log.py'
#   adding 'tos/mine_type.py'
#   adding 'tos/models.py'
#   adding 'tos/models2.py'
#   adding 'tos/safe_map.py'
#   adding 'tos/thread_ctx.py'
#   adding 'tos/utils.py'
#   adding 'tos-2.8.7.dist-info/licenses/LICENSE'
#   adding 'tos-2.8.7.dist-info/METADATA'
#   adding 'tos-2.8.7.dist-info/WHEEL'
#   adding 'tos-2.8.7.dist-info/top_level.txt'
#   adding 'tos-2.8.7.dist-info/RECORD'
#   removing build\bdist.win-amd64\wheel
#   Running command Building wheel for crcmod (pyproject.toml)
#   C:\Users\weiss\AppData\Local\Temp\pip-build-env-klh75cvi\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: MIT License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   _crcfunext.c
#     正在创建库 build\temp.win-amd64-cpython-312\Release\python3\src\_crcfunext.cp312-win_amd64.lib 和对象 build\temp.win-amd64-cpython-312\Release\python3\src\_crcfunext.cp312-win_amd64.exp
#   正在生成代码
#   已完成代码的生成
#   C:\Users\weiss\AppData\Local\Temp\pip-build-env-klh75cvi\overlay\Lib\site-packages\setuptools\command\bdist_wheel.py:103: RuntimeWarning: Config variable 'Py_DEBUG' is unset, Python ABI tag may be incorrect
#     if get_flag("Py_DEBUG", hasattr(sys, "gettotalrefcount"), warn=(impl == "cp")):
#   WARNING: Failed to remove contents in a temporary directory 'D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\cs\Anaconda3-24-10\envs\pytorch-study\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
import lightx2v
print(f"LightX2V 版本: {lightx2v.__version__}")
# Out:
# LightX2V 版本: 0.1.0

# %% [markdown]
# #### **使用Wan2.1-T2V-1.3B文升图：16.3G, 最高显存占用18.5G**

# %%
import os
# %matplotlib inline
import torch
import matplotlib.pyplot as plt
from diffusers import StableDiffusionPipeline
import accelerate
from PIL import Image
os.environ["DTYPE"] = "BF16"

# %%
from lightx2v import LightX2VPipeline
import torch

# ====================== 环境配置（5080 16G专用） ======================
torch.cuda.empty_cache()
torch.backends.cudnn.benchmark = True
torch.backends.cuda.matmul.allow_tf32 = True  # 5080开启TF32加速

# ====================== 初始化Pipeline（8bit量化核心） ======================
pipe = LightX2VPipeline(
    model_path="./Wan2.1-T2V-1.3B",
    model_cls="wan2.1",
    task="t2v",
)

pipe.create_generator(
    infer_steps=50,
    height=720, # 720
    width=480, # 1280
    num_frames=81,
    guidance_scale=5.0,
    sample_shift=5.0,
)

prompt = "一个漂亮的原神女coser在海边打着伞散步"
negative_prompt = "镜头晃动，色调艳丽，过曝，静态，细节模糊不清，字幕，风格，作品，画作，画面，静止，整体发灰，最差质量，低质量，JPEG压缩残留，丑陋的，残缺的，多余的手指，画得不好的手部，画得不好的脸部，畸形的，毁容的，形态畸形的肢体，手指融合，静止不动的画面，杂乱的背景，三条腿，背景人很多，倒着走"
save_result_path="./data/StableDiffusion/yuanshen.mp4"

pipe.generate(
    seed=42,
    prompt=prompt,
    negative_prompt=negative_prompt,
    save_result_path=save_result_path,
)
print(f"动画视频生成完成！保存至：{save_result_path}")

#清除显存占用
del pipe
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# 2026-01-13 18:07:53.332 | INFO     | lightx2v_platform.base.base:init_ai_device:16 - Initialized AI_DEVICE: cuda
# 2026-01-13 18:07:53.332 | INFO     | lightx2v_platform.base.base:check_ai_device:33 - AI device for platform 'cuda' is available.
# 2026-01-13 18:07:53.588 | INFO     | lightx2v.common.ops.attn.flash_attn:<module>:13 - flash_attn_varlen_func_v3 not found, please install flash_attn3 first
# 2026-01-13 18:07:53.598 | INFO     | lightx2v.common.ops.attn.sage_attn:<module>:25 - sageattn3 not found, please install sageattention first
# W0113 18:07:53.947000 31984 site-packages\torch\utils\cpp_extension.py:466] Error checking compiler version for cl: [WinError 2] 系统找不到指定的文件。
# 2026-01-13 18:07:53.979 | WARNING  | lightx2v.utils.quant_utils:<module>:7 - qtorch not found, please install qtorch.Please install qtorch (pip install qtorch).
# 2026-01-13 18:07:54.159 | INFO     | lightx2v.utils.set_config:print_config:116 - config:
# {
#     "do_mm_calib": false,
#     "cpu_offload": false,
#     "max_area": false,
#     "vae_stride": [
#         4,
#         8,
#         8
#     ],
#     "patch_size": [
#         1,
#         2,
#         2
#     ],
#     "feature_caching": "NoCaching",
#     "teacache_thresh": 0.26,
#     "use_ret_steps": false,
#     "use_bfloat16": true,
#     "lora_configs": null,
#     "use_prompt_enhancer": false,
#     "parallel": false,
#     "seq_parallel": false,
#     "cfg_parallel": false,
#     "enable_cfg": true,
#     "use_image_encoder": true,
#     "task": "t2v",
#     "model_path": "./Wan2.1-T2V-1.3B",
#     "model_cls": "wan2.1",
#     "sf_model_path": null,
#     "dit_original_ckpt": null,
#     "low_noise_original_ckpt": null,
#     "high_noise_original_ckpt": null,
#     "transformer_model_name": null,
#     "infer_steps": 50,
#     "target_width": 480,
#     "target_height": 720,
#     "target_video_length": 81,
#     "sample_guide_scale": 5.0,
#     "sample_shift": 5.0,
#     "rope_type": "torch",
#     "fps": 16,
#     "boundary": 0.9,
#     "boundary_step_index": 2,
#     "denoising_step_list": [
#         1000,
#         750,
#         500,
#         250
#     ],
#     "self_attn_1_type": "flash_attn2",
#     "cross_attn_1_type": "flash_attn2",
#     "cross_attn_2_type": "flash_attn2",
#     "_class_name": "WanModel",
#     "_diffusers_version": "0.30.0",
#     "dim": 1536,
#     "eps": 1e-06,
#     "ffn_dim": 8960,
#     "freq_dim": 256,
#     "in_dim": 16,
#     "model_type": "t2v",
#     "num_heads": 12,
#     "num_layers": 30,
#     "out_dim": 16,
#     "text_len": 512,
#     "attnmap_frame_num": 21
# }
# 2026-01-13 18:07:54.227 | INFO     | lightx2v.models.runners.default_runner:init_modules:65 - Initializing runner modules...
# 2026-01-13 18:07:54.227 | INFO     | lightx2v.utils.custom_compiler:_discover_compiled_methods:120 - [Compile] Discovering compiled methods for WanModel...
# 2026-01-13 18:07:54.228 | INFO     | lightx2v.utils.custom_compiler:_discover_compiled_methods:125 - [Compile] Found compiled method: _infer_cond_uncond
# 2026-01-13 18:07:54.228 | INFO     | lightx2v.models.networks.wan.model:_load_ckpt:195 - Loading weights from ./Wan2.1-T2V-1.3B\diffusion_pytorch_model.safetensors
# 2026-01-13 18:07:56.194 | INFO     | lightx2v.utils.utils:load_weights:388 - Loading weights from ./Wan2.1-T2V-1.3B\models_t5_umt5-xxl-enc-bf16.pth
# 2026-01-13 18:07:59.609 | INFO     | lightx2v.utils.utils:load_weights:388 - Loading weights from ./Wan2.1-T2V-1.3B\Wan2.1_VAE.pth
# 2026-01-13 18:07:59.756 | INFO     | lightx2v.pipeline:create_generator:166 - Initializing wan2.1 runner for t2v task...
# 2026-01-13 18:07:59.757 | INFO     | lightx2v.pipeline:create_generator:167 - Model path: ./Wan2.1-T2V-1.3B
# 2026-01-13 18:07:59.757 | INFO     | lightx2v.pipeline:create_generator:168 - LightGenerator initialized successfully!
# 2026-01-13 18:08:00.235 | INFO     | lightx2v.models.runners.default_runner:run_main:357 - 🔄 start segment 1/1
# 2026-01-13 18:08:00.236 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 1 / 50
# 2026-01-13 18:08:23.264 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 2 / 50
# 2026-01-13 18:08:51.602 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 3 / 50
# 2026-01-13 18:09:19.879 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 4 / 50
# 2026-01-13 18:09:47.959 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 5 / 50
# 2026-01-13 18:10:16.083 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 6 / 50
# 2026-01-13 18:10:44.167 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 7 / 50
# 2026-01-13 18:11:12.117 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 8 / 50
# 2026-01-13 18:11:40.088 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 9 / 50
# 2026-01-13 18:12:08.226 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 10 / 50
# 2026-01-13 18:12:36.313 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 11 / 50
# 2026-01-13 18:13:04.279 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 12 / 50
# 2026-01-13 18:13:32.474 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 13 / 50
# 2026-01-13 18:14:00.864 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 14 / 50
# 2026-01-13 18:14:29.861 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 15 / 50
# 2026-01-13 18:14:58.760 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 16 / 50
# 2026-01-13 18:15:27.483 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 17 / 50
# 2026-01-13 18:15:55.439 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 18 / 50
# 2026-01-13 18:16:23.474 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 19 / 50
# 2026-01-13 18:16:51.395 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 20 / 50
# 2026-01-13 18:17:19.476 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 21 / 50
# 2026-01-13 18:17:47.495 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 22 / 50
# 2026-01-13 18:18:15.663 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 23 / 50
# 2026-01-13 18:18:43.668 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 24 / 50
# 2026-01-13 18:19:11.707 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 25 / 50
# 2026-01-13 18:19:39.789 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 26 / 50
# 2026-01-13 18:20:07.870 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 27 / 50
# 2026-01-13 18:20:35.957 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 28 / 50
# 2026-01-13 18:21:04.079 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 29 / 50
# 2026-01-13 18:21:32.267 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 30 / 50
# 2026-01-13 18:22:00.616 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 31 / 50
# 2026-01-13 18:22:28.619 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 32 / 50
# 2026-01-13 18:22:56.673 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 33 / 50
# 2026-01-13 18:23:24.343 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 34 / 50
# 2026-01-13 18:23:52.312 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 35 / 50
# 2026-01-13 18:24:20.488 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 36 / 50
# 2026-01-13 18:24:48.543 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 37 / 50
# 2026-01-13 18:25:16.590 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 38 / 50
# 2026-01-13 18:25:44.845 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 39 / 50
# 2026-01-13 18:26:13.041 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 40 / 50
# 2026-01-13 18:26:41.089 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 41 / 50
# 2026-01-13 18:27:09.214 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 42 / 50
# 2026-01-13 18:27:37.325 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 43 / 50
# 2026-01-13 18:28:05.424 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 44 / 50
# 2026-01-13 18:28:33.630 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 45 / 50
# 2026-01-13 18:29:01.657 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 46 / 50
# 2026-01-13 18:29:29.788 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 47 / 50
# 2026-01-13 18:29:57.902 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 48 / 50
# 2026-01-13 18:30:26.036 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 49 / 50
# 2026-01-13 18:30:54.028 | INFO     | lightx2v.models.runners.default_runner:run_segment:177 - ==> step_index: 50 / 50
# 2026-01-13 18:31:22.114 | INFO     | lightx2v.utils.memory_profiler:wrapper:23 - Function 'DefaultRunner.run_segment' Peak Memory: 14.82 GB
# 2026-01-13 18:40:01.643 | INFO     | lightx2v.models.runners.default_runner:process_images_after_vae_decoder:446 - 🎬 Start to save video 🎬
# 2026-01-13 18:40:02.170 | INFO     | lightx2v.models.runners.default_runner:process_images_after_vae_decoder:449 - ✅ Video saved successfully to: ./data/StableDiffusion/yuanshen.mp4 ✅
# 2026-01-13 18:40:02.595 | INFO     | lightx2v.pipeline:generate:378 - Video generated successfully!
# 2026-01-13 18:40:02.596 | INFO     | lightx2v.pipeline:generate:379 - Video Saved in ./data/StableDiffusion/yuanshen.mp4
# 动画视频生成完成！保存至：./data/StableDiffusion/yuanshen.mp4
# 2207

# %%
from IPython.display import Video

# 显示本地视频（替换为你的视频路径）
video_path = "./data/StableDiffusion/yuanshen.mp4"  # 你生成的视频路径
Video(video_path, width=480, height=720, embed=True)
# Out:
# <video controls  width="480"  height="720">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# #### **目前还未成功**
# 在命令行激活当前python环境，然后执行下面命令， **117G注意** wan2.2文生视频模型
# huggingface-cli download Wan-AI/Wan2.2-T2V-A14B --local-dir ./Wan2.2-T2V-A14B

# %%
# from lightx2v import LightX2VPipeline
# import torch

# # ====================== 环境配置（5080 16G专用） ======================
# torch.cuda.empty_cache()
# torch.backends.cudnn.benchmark = True
# torch.backends.cuda.matmul.allow_tf32 = True  # 5080开启TF32加速

# # ====================== 初始化Pipeline（8bit量化核心） ======================
# pipe = LightX2VPipeline(
#     model_path="./Wan2.2-T2V-A14B",
#     model_cls="wan2.2",
#     task="t2v",
# )

# pipe.create_generator(
#     attn_mode="sage_attn2",
#     infer_steps=50,
#     height=480, # 720
#     width=832, # 1280
#     num_frames=81,
#     guidance_scale=5.0,
#     sample_shift=5.0,
# )

# prompt = "Two anthropomorphic cats in comfy boxing gear and bright gloves fight intensely on a spotlighted stage."
# negative_prompt = "镜头晃动，色调艳丽，过曝，静态，细节模糊不清，字幕，风格，作品，画作，画面，静止，整体发灰，最差质量，低质量，JPEG压缩残留，丑陋的，残缺的，多余的手指，画得不好的手部，画得不好的脸部，畸形的，毁容的，形态畸形的肢体，手指融合，静止不动的画面，杂乱的背景，三条腿，背景人很多，倒着走"
# save_result_path="./data/StableDiffusion/output.mp4"

# pipe.generate(
#     seed=42,
#     prompt=prompt,
#     negative_prompt=negative_prompt,
#     save_result_path=save_result_path,
# )
# print(f"动画视频生成完成！保存至：{save_result_path}")

# %% [markdown]
# ## 学习使用ControlNet 可控生图 的使用

# %% [markdown]
# ## 学习LoRA微调

# %% [markdown]
# ## StableDiffusion的详细实现

# %% [markdown]
# ## 学习使用ComfyUI（可能写不到这上面来）
